# %%
import os
import time
import pylab
import torch
import pickle
import numpy as np
from math import *
import matplotlib as mpl
from cycler import cycler
from numpy.linalg import *
import matplotlib.pyplot as plt
from utils.couzin_utils import *
from mpl_toolkits.mplot3d import Axes3D

# %%
# https://github.com/hossein-haeri/couzin_swarm_model/blob/master/swarm_pray_predator.py

# %%
mpl.use('TkAgg')
visualization = 'on'   # 'on' / 'off'
max_steps = 1000        # maximum simulation steps
alpha = 0.1            # 1 = only social, 0 = only escape
number_of_sharks = 1
number_of_prey = 32

pred_tensor, prey_tensor, pred_log, prey_log = run_couzin_simulation(visualization=visualization, max_steps=max_steps, alpha=alpha)

# %%
path = r"..\data\processed\couzin_interactions"

# Predator
pred_path = os.path.join(path, "pred_couzin_interactions.pkl")
with open(pred_path, "wb") as f:
    pickle.dump(torch.from_numpy(pred_tensor).float(), f)

# Prey
prey_path = os.path.join(path, "prey_couzin_interactions.pkl")
with open(prey_path, "wb") as f:
    pickle.dump(torch.from_numpy(prey_tensor).float(), f)
