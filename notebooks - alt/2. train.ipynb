# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pickle
import datetime
import custom_marl_aquarium
from utils.es_utils import *
from utils.env_utils import *
from utils.train_utils import *
from models.Buffer import Buffer, Pool
from models.PreyPolicy import PreyPolicy
from models.PredatorPolicy import PredatorPolicy
from models.Discriminator import Discriminator

# %%
"""
ToDo's
- Umgang mit Mode Collapse?
- AnyDesk Daten kopieren und processen

- Multi Objective Training - Distance to Predator, Escape Alignment

Hinweis:
- Falls Pretraining mit BC - danach Modell auf CPU schieben
"""
# Out:
# "\nToDo's\n- Umgang mit Mode Collapse?\n- Training auf GPU\n- Gamma bei pred_gain mit tunen\n\n- Discriminator konvergiert werden Output 0.5, heißt er macht Coin-Flip bei jedem Case.\n- Speed Metriken und Velocity Metric bei Scaling und als Input-Vector prüfen!\n- Multi Objective Training:\n\nfitness = disc_reward           + λ1 * ( - |polarization - polarization_expert| )           + λ2 * ( - |distance_to_predator - target_dist| )           + λ3 * ( - |escape_alignment - target_escape| )\n\n"

# %%
# Hyperparameters

# generated_trajectories
gt_gen_episodes = 50
gt_clip_length = 30

# Training
num_generations = 61
pred_batch_size = 256
prey_batch_size = 512
gen_dis_ratio = 1

# Polcy Update
num_perturbations = 32
pert_clip_length = 22
sigma = 0.0703153292486112               
gamma = 0.9995             
lr_pred_pin = 0.0007442062051182169
lr_pred_an = 0.00008326162744937111    
lr_prey_pin = 0.00010296057739631855
lr_prey_an = 0.00007160898826391525
lr_prey_pred_pin = 0.0005573836216821976

# Discriminator Update
lr_pred_dis =  1.4355130033773653e-05
lr_prey_dis =  1.0493552789683608e-04
alpha = 0.99
eps_dis = 1e-08
lambda_gp_pred = 9
lambda_gp_prey = 9

# Early Stopping
start_es_pred = 1000
start_es_prey = 1000
patience = 1000

# %%
# Create training folder
path = rf"..\data\2. Training\training\GAIL"
timestamp = datetime.datetime.now().strftime("%d.%m.%Y_%H.%M")
folder_name = f"GAIL Training - {timestamp}"
save_dir = os.path.join(path, folder_name)
os.makedirs(save_dir, exist_ok=True)

# Expert Data
traj_path = rf'..\data\1. Data Processing\processed\video\expert_tensors\yolo_detected'
hl_path = rf'..\data\1. Data Processing\processed\video\expert_tensors\hand_labeled'
ftw_path = rf'..\data\1. Data Processing\processed\video\3. full_track_windows'

# %%
device = torch.device("cpu") # Use CPU for GAIL training due to PoolThreading issues with GPU

pred_policy = PredatorPolicy().to(device)
pred_policy.set_parameters(init=True)

prey_policy = PreyPolicy().to(device)
prey_policy.set_parameters(init=True)

pred_discriminator = Discriminator().to(device)
pred_discriminator.set_parameters(init=True)
optim_dis_pred = torch.optim.RMSprop(pred_discriminator.parameters(), lr=lr_pred_dis, alpha=alpha, eps=eps_dis)

prey_discriminator = Discriminator().to(device)
prey_discriminator.set_parameters(init=True)
optim_dis_prey = torch.optim.RMSprop(prey_discriminator.parameters(), lr=lr_prey_dis, alpha=alpha, eps=eps_dis)

expert_buffer = Buffer(pred_max_length=23000, prey_max_length=73000, device=device)

len_gb_pred = gt_gen_episodes * gt_clip_length * 3
len_gb_prey = gt_gen_episodes * gt_clip_length * 3 * 32 # completly update reply buffer after three generations
generative_buffer = Buffer(pred_max_length=len_gb_pred, prey_max_length=len_gb_prey, device=device)

start_frame_pool = Pool(max_length=13000, device=device)
start_frame_pool.generate_startframes(ftw_path)

early_stopper_pred = EarlyStoppingWasserstein(patience=patience, start_es=start_es_pred)
early_stopper_prey = EarlyStoppingWasserstein(patience=patience, start_es=start_es_prey)

# %%
# Load Expert Data from local storage
print("Expert Buffer is empty, load data...")
expert_buffer.add_expert(traj_path)
expert_buffer.clear(p=50)               # Reduce ratio of non-attack data by 90%. now ~equal
expert_buffer.add_expert(hl_path)       # hand-labeled data | Pred: 1057 | Prey: 33824

len_exp_pred, len_exp_prey = expert_buffer.lengths()
print("Storage of Predator Expert Buffer: ", len_exp_pred)
print("Storage of Prey Expert Buffer: ", len_exp_prey, "\n")
# Out:
# Expert Buffer is empty, load data...
# Storage of Predator Expert Buffer:  11767
# Storage of Prey Expert Buffer:  70324

# %%
# Generate Trajectories for Generative Buffer
print("Generative Buffer is empty, generating data...")
generate_trajectories(buffer=generative_buffer, start_frame_pool=start_frame_pool,
                      pred_policy=pred_policy, prey_policy=prey_policy, 
                      clip_length=gt_clip_length, num_generative_episodes=gt_gen_episodes,
                      use_walls=True)

len_gen_pred, len_gen_prey = generative_buffer.lengths()
print("Storage of Predator Generative Buffer: ", len_gen_pred)
print("Storage of Prey Generative Buffer: ", len_gen_prey)
# Out:
# Generative Buffer is empty, generating data...
# Storage of Predator Generative Buffer:  1500
# Storage of Prey Generative Buffer:  48000

# %%
dis_metrics_pred = []
dis_metrics_prey = []

es_metrics_pred = []
es_metrics_prey = []

for generation in range(num_generations):
    start_time = time.time()
    
    # Sample traj from expert and generative buffer
    expert_pred_batch, expert_prey_batch = expert_buffer.sample(pred_batch_size, prey_batch_size)
    policy_pred_batch, policy_prey_batch = generative_buffer.sample(pred_batch_size, prey_batch_size)

    # Predator discriminator update
    dis_metric_pred = pred_discriminator.update(expert_pred_batch, policy_pred_batch, optim_dis_pred, lambda_gp_pred)
    dis_metrics_pred.append(dis_metric_pred)
                                     
    # Prey discriminator update
    dis_metric_prey = prey_discriminator.update(expert_prey_batch, policy_prey_batch, optim_dis_prey, lambda_gp_prey)
    dis_metrics_prey.append(dis_metric_prey)

    for i in range(gen_dis_ratio):
        pred_stats = pred_policy.update("predator", "pairwise",
                                        pred_policy, prey_policy,
                                        pred_discriminator, prey_discriminator,
                                        num_perturbations, generation, lr_pred_pin,
                                        sigma, clip_length=pert_clip_length,
                                        use_walls=True, start_frame_pool=start_frame_pool)
        print(f"[PREDATOR] Pairwise Interaction Network updated! [{i+1}/{gen_dis_ratio}]")
        

        pred_stats += pred_policy.update("predator", "attention",
                                        pred_policy, prey_policy,
                                        pred_discriminator, prey_discriminator,
                                        num_perturbations, generation, lr_pred_an,
                                        sigma, clip_length=pert_clip_length,
                                        use_walls=True, start_frame_pool=start_frame_pool)
        es_metrics_pred.append(pred_stats)
        print(f"[PREDATOR] Attention Network updated! [{i+1}/{gen_dis_ratio}]")


        prey_stats = prey_policy.update("prey", "prey_pairwise",
                                        pred_policy, prey_policy,
                                        pred_discriminator, prey_discriminator,
                                        num_perturbations, generation, lr_prey_pin,
                                        sigma, clip_length=pert_clip_length,
                                        use_walls=True, start_frame_pool=start_frame_pool)
        print(f"[PREY] Pairwise Interaction Network updated! [{i+1}/{gen_dis_ratio}]")
        
        prey_stats += prey_policy.update("prey", "prey_attention",
                                        pred_policy, prey_policy,
                                        pred_discriminator, prey_discriminator,
                                        num_perturbations, generation, lr_prey_an,
                                        sigma, clip_length=pert_clip_length,
                                        use_walls=True, start_frame_pool=start_frame_pool)
        es_metrics_prey.append(prey_stats)
        print(f"[PREY] Attention Network updated! [{i+1}/{gen_dis_ratio}]")

        prey_stats += prey_policy.update("prey", "pred_pairwise",
                                        pred_policy, prey_policy,
                                        pred_discriminator, prey_discriminator,
                                        num_perturbations, generation, lr_prey_pred_pin,
                                        sigma, clip_length=pert_clip_length,
                                        use_walls=True, start_frame_pool=start_frame_pool)
        es_metrics_prey.append(prey_stats)
        print(f"[PREY] Predator Pairwise Interaction Network updated! [{i+1}/{gen_dis_ratio}]\n")


        # Generate new trajectories with updated policies
        generate_trajectories(buffer=generative_buffer, start_frame_pool=start_frame_pool,
                              pred_policy=pred_policy, prey_policy=prey_policy, 
                              clip_length=gt_clip_length, num_generative_episodes=gt_gen_episodes,
                              use_walls=True)

    lr_pred_pin *= gamma
    lr_pred_an *= gamma
    lr_prey_pin *= gamma
    lr_prey_an *= gamma
    lr_prey_pred_pin *= gamma
    sigma *= gamma

    last_epoch_duration = time.time() - start_time
    estimated_time, epoch_time = remaining_time(num_generations, last_epoch_duration, current_generation=generation)

    avg_es_pred = np.mean([m['reward_mean'] for m in pred_stats])
    avg_es_prey = np.mean([m['reward_mean'] for m in prey_stats])

    avg_grad_norm_pred = np.mean([m['grad_norm'] for m in pred_stats])
    avg_grad_norm_prey = np.mean([m['grad_norm'] for m in prey_stats])
        
    print(f"[Generation {generation+1}/{num_generations}] - Time: {epoch_time} - Estimated Finish: {estimated_time}" )
    print(f"Predator | ES-Reward: {avg_es_pred:.3f} | Wasserstein Loss: {dis_metric_pred[0]:.3f} | GP: {dis_metric_pred[1]:.3f} | Grad: {avg_grad_norm_pred:.3f} | Expert Scores: {dis_metric_pred[2]:.3f} | Policy Scores: {dis_metric_pred[3]:.3f}")
    print(f"Prey     | ES-Reward: {avg_es_prey:.3f} | Wasserstein Loss: {dis_metric_prey[0]:.3f} | GP: {dis_metric_prey[1]:.3f} | Grad: {avg_grad_norm_prey:.3f} | Expert Scores: {dis_metric_prey[2]:.3f} | Policy Scores: {dis_metric_prey[3]:.3f}\n")

    if early_stopper_pred(dis_metric_pred[0], generation, "predator") or early_stopper_prey(dis_metric_prey[0], generation, "prey"):
        break

    if generation % 10 == 0:
        save_checkpoint(save_dir, generation,
                        pred_policy, prey_policy,
                        pred_discriminator, prey_discriminator,
                        optim_dis_pred, optim_dis_prey,
                        expert_buffer, generative_buffer,
                        dis_metrics_pred, dis_metrics_prey,
                        es_metrics_pred, es_metrics_prey)


# Save models
save_models(save_dir,
            pred_policy, prey_policy,
            pred_discriminator, prey_discriminator,
            optim_dis_pred, optim_dis_prey,
            expert_buffer, generative_buffer,
            dis_metrics_pred, dis_metrics_prey,
            es_metrics_pred, es_metrics_prey)
# Out:
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 1/61] - Time: 15:26 - Estimated Finish: 05.12.2025 14:32:00
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.937 | GP: 0.884 | Grad: 981.794 | Expert Scores: -0.155 | Policy Scores: -0.169
# Prey     | ES-Reward: 0.000 | Wasserstein Loss: 7.743 | GP: 0.859 | Grad: 103.197 | Expert Scores: -0.145 | Policy Scores: -0.133
#
# Checkpoint successfully saved!
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 2/61] - Time: 15:29 - Estimated Finish: 05.12.2025 14:35:19
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.898 | GP: 0.880 | Grad: 907.498 | Expert Scores: -0.151 | Policy Scores: -0.173
# Prey     | ES-Reward: -0.000 | Wasserstein Loss: 7.603 | GP: 0.845 | Grad: 134.566 | Expert Scores: -0.147 | Policy Scores: -0.151
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 3/61] - Time: 15:31 - Estimated Finish: 05.12.2025 14:36:34
# Predator | ES-Reward: 0.001 | Wasserstein Loss: 7.877 | GP: 0.877 | Grad: 2014.602 | Expert Scores: -0.153 | Policy Scores: -0.171
# Prey     | ES-Reward: 0.000 | Wasserstein Loss: 7.511 | GP: 0.836 | Grad: 113.506 | Expert Scores: -0.150 | Policy Scores: -0.160
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 4/61] - Time: 15:20 - Estimated Finish: 05.12.2025 14:26:47
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.868 | GP: 0.877 | Grad: 1688.818 | Expert Scores: -0.151 | Policy Scores: -0.172
# Prey     | ES-Reward: -0.001 | Wasserstein Loss: 7.392 | GP: 0.824 | Grad: 133.898 | Expert Scores: -0.147 | Policy Scores: -0.170
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [DEBUG|ES] rewards_norm mean/std: 14781.913272691556 7919.2724383598315
#            grad norm: 2805307.75
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 5/61] - Time: 15:15 - Estimated Finish: 05.12.2025 14:21:11
# Predator | ES-Reward: -0.002 | Wasserstein Loss: 7.848 | GP: 0.874 | Grad: 1683.761 | Expert Scores: -0.154 | Policy Scores: -0.173
# Prey     | ES-Reward: 0.001 | Wasserstein Loss: 7.308 | GP: 0.815 | Grad: 371.471 | Expert Scores: -0.150 | Policy Scores: -0.176
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 6/61] - Time: 15:16 - Estimated Finish: 05.12.2025 14:22:54
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.848 | GP: 0.875 | Grad: 12653.486 | Expert Scores: -0.152 | Policy Scores: -0.175
# Prey     | ES-Reward: 0.001 | Wasserstein Loss: 7.148 | GP: 0.798 | Grad: 108.165 | Expert Scores: -0.151 | Policy Scores: -0.189
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 7/61] - Time: 15:18 - Estimated Finish: 05.12.2025 14:24:26
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.853 | GP: 0.876 | Grad: 1107.888 | Expert Scores: -0.151 | Policy Scores: -0.177
# Prey     | ES-Reward: 0.002 | Wasserstein Loss: 7.031 | GP: 0.786 | Grad: 97.388 | Expert Scores: -0.152 | Policy Scores: -0.196
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 8/61] - Time: 15:17 - Estimated Finish: 05.12.2025 14:23:58
# Predator | ES-Reward: 0.001 | Wasserstein Loss: 7.866 | GP: 0.877 | Grad: 1144.375 | Expert Scores: -0.153 | Policy Scores: -0.178
# Prey     | ES-Reward: -0.001 | Wasserstein Loss: 6.926 | GP: 0.775 | Grad: 121.109 | Expert Scores: -0.154 | Policy Scores: -0.205
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 9/61] - Time: 15:19 - Estimated Finish: 05.12.2025 14:25:10
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.851 | GP: 0.876 | Grad: 761.286 | Expert Scores: -0.149 | Policy Scores: -0.181
# Prey     | ES-Reward: -0.000 | Wasserstein Loss: 6.847 | GP: 0.766 | Grad: 84.480 | Expert Scores: -0.155 | Policy Scores: -0.202
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 10/61] - Time: 15:21 - Estimated Finish: 05.12.2025 14:26:37
# Predator | ES-Reward: 0.001 | Wasserstein Loss: 7.796 | GP: 0.870 | Grad: 848.836 | Expert Scores: -0.151 | Policy Scores: -0.188
# Prey     | ES-Reward: 0.000 | Wasserstein Loss: 6.823 | GP: 0.764 | Grad: 79.644 | Expert Scores: -0.156 | Policy Scores: -0.207
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 11/61] - Time: 15:09 - Estimated Finish: 05.12.2025 14:16:51
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.801 | GP: 0.870 | Grad: 878.995 | Expert Scores: -0.152 | Policy Scores: -0.184
# Prey     | ES-Reward: 0.002 | Wasserstein Loss: 6.655 | GP: 0.746 | Grad: 83.074 | Expert Scores: -0.158 | Policy Scores: -0.219
#
# Checkpoint successfully saved!
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 12/61] - Time: 15:09 - Estimated Finish: 05.12.2025 14:17:00
# Predator | ES-Reward: 0.001 | Wasserstein Loss: 7.803 | GP: 0.871 | Grad: 1669.470 | Expert Scores: -0.151 | Policy Scores: -0.188
# Prey     | ES-Reward: 0.002 | Wasserstein Loss: 6.551 | GP: 0.736 | Grad: 153.021 | Expert Scores: -0.158 | Policy Scores: -0.228
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 13/61] - Time: 15:03 - Estimated Finish: 05.12.2025 14:12:09
# Predator | ES-Reward: 0.001 | Wasserstein Loss: 7.809 | GP: 0.871 | Grad: 4877.725 | Expert Scores: -0.151 | Policy Scores: -0.182
# Prey     | ES-Reward: 0.003 | Wasserstein Loss: 6.341 | GP: 0.714 | Grad: 76.942 | Expert Scores: -0.159 | Policy Scores: -0.247
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 14/61] - Time: 15:17 - Estimated Finish: 05.12.2025 14:23:25
# Predator | ES-Reward: -0.001 | Wasserstein Loss: 7.774 | GP: 0.868 | Grad: 1972.617 | Expert Scores: -0.151 | Policy Scores: -0.189
# Prey     | ES-Reward: 0.000 | Wasserstein Loss: 6.302 | GP: 0.711 | Grad: 81.912 | Expert Scores: -0.161 | Policy Scores: -0.255
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 15/61] - Time: 15:21 - Estimated Finish: 05.12.2025 14:26:27
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.764 | GP: 0.867 | Grad: 2078.908 | Expert Scores: -0.151 | Policy Scores: -0.189
# Prey     | ES-Reward: 0.004 | Wasserstein Loss: 6.178 | GP: 0.698 | Grad: 61.645 | Expert Scores: -0.162 | Policy Scores: -0.262
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 16/61] - Time: 15:21 - Estimated Finish: 05.12.2025 14:26:31
# Predator | ES-Reward: -0.001 | Wasserstein Loss: 7.765 | GP: 0.867 | Grad: 1361.036 | Expert Scores: -0.151 | Policy Scores: -0.187
# Prey     | ES-Reward: -0.002 | Wasserstein Loss: 6.101 | GP: 0.688 | Grad: 55.762 | Expert Scores: -0.162 | Policy Scores: -0.253
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 17/61] - Time: 15:20 - Estimated Finish: 05.12.2025 14:25:25
# Predator | ES-Reward: 0.001 | Wasserstein Loss: 7.772 | GP: 0.867 | Grad: 1134.918 | Expert Scores: -0.152 | Policy Scores: -0.185
# Prey     | ES-Reward: 0.005 | Wasserstein Loss: 6.033 | GP: 0.679 | Grad: 48.932 | Expert Scores: -0.167 | Policy Scores: -0.250
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 18/61] - Time: 15:20 - Estimated Finish: 05.12.2025 14:25:44
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.797 | GP: 0.870 | Grad: 1222.781 | Expert Scores: -0.151 | Policy Scores: -0.181
# Prey     | ES-Reward: -0.006 | Wasserstein Loss: 5.902 | GP: 0.666 | Grad: 43.576 | Expert Scores: -0.167 | Policy Scores: -0.258
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 19/61] - Time: 15:20 - Estimated Finish: 05.12.2025 14:25:37
# Predator | ES-Reward: -0.001 | Wasserstein Loss: 7.796 | GP: 0.869 | Grad: 2166.983 | Expert Scores: -0.150 | Policy Scores: -0.178
# Prey     | ES-Reward: -0.001 | Wasserstein Loss: 5.782 | GP: 0.653 | Grad: 52.598 | Expert Scores: -0.170 | Policy Scores: -0.264
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 20/61] - Time: 15:19 - Estimated Finish: 05.12.2025 14:25:07
# Predator | ES-Reward: -0.002 | Wasserstein Loss: 7.762 | GP: 0.866 | Grad: 1453.712 | Expert Scores: -0.151 | Policy Scores: -0.187
# Prey     | ES-Reward: 0.002 | Wasserstein Loss: 5.649 | GP: 0.639 | Grad: 59.142 | Expert Scores: -0.171 | Policy Scores: -0.273
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 21/61] - Time: 15:13 - Estimated Finish: 05.12.2025 14:20:53
# Predator | ES-Reward: -0.001 | Wasserstein Loss: 7.773 | GP: 0.868 | Grad: 3453.173 | Expert Scores: -0.151 | Policy Scores: -0.186
# Prey     | ES-Reward: -0.001 | Wasserstein Loss: 5.589 | GP: 0.633 | Grad: 39.693 | Expert Scores: -0.172 | Policy Scores: -0.282
#
# Checkpoint successfully saved!
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 22/61] - Time: 15:20 - Estimated Finish: 05.12.2025 14:25:43
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.758 | GP: 0.866 | Grad: 759.326 | Expert Scores: -0.150 | Policy Scores: -0.186
# Prey     | ES-Reward: 0.004 | Wasserstein Loss: 5.442 | GP: 0.618 | Grad: 48.267 | Expert Scores: -0.171 | Policy Scores: -0.290
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [DEBUG|ES] rewards_norm mean/std: 1412.912963141211 790.7379702737687
#            grad norm: 268078.46875
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 23/61] - Time: 15:21 - Estimated Finish: 05.12.2025 14:26:18
# Predator | ES-Reward: 0.001 | Wasserstein Loss: 7.752 | GP: 0.865 | Grad: 848.256 | Expert Scores: -0.151 | Policy Scores: -0.186
# Prey     | ES-Reward: 0.001 | Wasserstein Loss: 5.373 | GP: 0.610 | Grad: 55.285 | Expert Scores: -0.174 | Policy Scores: -0.291
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 24/61] - Time: 15:19 - Estimated Finish: 05.12.2025 14:25:08
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.775 | GP: 0.868 | Grad: 1654.939 | Expert Scores: -0.151 | Policy Scores: -0.187
# Prey     | ES-Reward: 0.004 | Wasserstein Loss: 5.217 | GP: 0.595 | Grad: 45.731 | Expert Scores: -0.175 | Policy Scores: -0.313
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 25/61] - Time: 15:21 - Estimated Finish: 05.12.2025 14:26:06
# Predator | ES-Reward: 0.001 | Wasserstein Loss: 7.772 | GP: 0.867 | Grad: 1098.982 | Expert Scores: -0.153 | Policy Scores: -0.187
# Prey     | ES-Reward: 0.004 | Wasserstein Loss: 5.112 | GP: 0.583 | Grad: 34.072 | Expert Scores: -0.178 | Policy Scores: -0.312
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 26/61] - Time: 15:17 - Estimated Finish: 05.12.2025 14:23:49
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.755 | GP: 0.866 | Grad: 1045.284 | Expert Scores: -0.150 | Policy Scores: -0.185
# Prey     | ES-Reward: -0.001 | Wasserstein Loss: 4.982 | GP: 0.570 | Grad: 46.464 | Expert Scores: -0.181 | Policy Scores: -0.334
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 27/61] - Time: 15:17 - Estimated Finish: 05.12.2025 14:24:11
# Predator | ES-Reward: -0.002 | Wasserstein Loss: 7.733 | GP: 0.864 | Grad: 1495.443 | Expert Scores: -0.150 | Policy Scores: -0.190
# Prey     | ES-Reward: -0.001 | Wasserstein Loss: 4.862 | GP: 0.556 | Grad: 51.470 | Expert Scores: -0.180 | Policy Scores: -0.325
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 28/61] - Time: 15:20 - Estimated Finish: 05.12.2025 14:25:40
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.740 | GP: 0.865 | Grad: 1095.574 | Expert Scores: -0.149 | Policy Scores: -0.195
# Prey     | ES-Reward: 0.007 | Wasserstein Loss: 4.737 | GP: 0.544 | Grad: 33.005 | Expert Scores: -0.181 | Policy Scores: -0.343
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 29/61] - Time: 15:19 - Estimated Finish: 05.12.2025 14:25:08
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.730 | GP: 0.864 | Grad: 1611.111 | Expert Scores: -0.151 | Policy Scores: -0.195
# Prey     | ES-Reward: -0.006 | Wasserstein Loss: 4.639 | GP: 0.534 | Grad: 20.629 | Expert Scores: -0.186 | Policy Scores: -0.353
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 30/61] - Time: 15:19 - Estimated Finish: 05.12.2025 14:25:05
# Predator | ES-Reward: 0.001 | Wasserstein Loss: 7.698 | GP: 0.860 | Grad: 791.048 | Expert Scores: -0.151 | Policy Scores: -0.197
# Prey     | ES-Reward: 0.005 | Wasserstein Loss: 4.448 | GP: 0.515 | Grad: 39.142 | Expert Scores: -0.182 | Policy Scores: -0.367
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 31/61] - Time: 15:19 - Estimated Finish: 05.12.2025 14:25:13
# Predator | ES-Reward: 0.001 | Wasserstein Loss: 7.716 | GP: 0.862 | Grad: 708.889 | Expert Scores: -0.152 | Policy Scores: -0.196
# Prey     | ES-Reward: -0.004 | Wasserstein Loss: 4.408 | GP: 0.511 | Grad: 27.475 | Expert Scores: -0.189 | Policy Scores: -0.377
#
# Checkpoint successfully saved!
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 32/61] - Time: 15:24 - Estimated Finish: 05.12.2025 14:27:44
# Predator | ES-Reward: -0.001 | Wasserstein Loss: 7.742 | GP: 0.865 | Grad: 679.630 | Expert Scores: -0.150 | Policy Scores: -0.191
# Prey     | ES-Reward: 0.005 | Wasserstein Loss: 4.296 | GP: 0.497 | Grad: 22.718 | Expert Scores: -0.191 | Policy Scores: -0.365
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 33/61] - Time: 15:20 - Estimated Finish: 05.12.2025 14:26:00
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.703 | GP: 0.860 | Grad: 418.164 | Expert Scores: -0.151 | Policy Scores: -0.192
# Prey     | ES-Reward: -0.001 | Wasserstein Loss: 4.205 | GP: 0.488 | Grad: 22.439 | Expert Scores: -0.191 | Policy Scores: -0.377
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 34/61] - Time: 15:22 - Estimated Finish: 05.12.2025 14:26:54
# Predator | ES-Reward: -0.001 | Wasserstein Loss: 7.707 | GP: 0.862 | Grad: 1492.514 | Expert Scores: -0.148 | Policy Scores: -0.198
# Prey     | ES-Reward: -0.003 | Wasserstein Loss: 4.136 | GP: 0.481 | Grad: 58.773 | Expert Scores: -0.188 | Policy Scores: -0.379
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 35/61] - Time: 15:24 - Estimated Finish: 05.12.2025 14:27:37
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.681 | GP: 0.858 | Grad: 1265.618 | Expert Scores: -0.151 | Policy Scores: -0.197
# Prey     | ES-Reward: -0.002 | Wasserstein Loss: 4.038 | GP: 0.472 | Grad: 32.009 | Expert Scores: -0.189 | Policy Scores: -0.396
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [DEBUG|ES] rewards_norm mean/std: 188.0406609030221 105.30319826631657
#            grad norm: 35438.12890625
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 36/61] - Time: 15:25 - Estimated Finish: 05.12.2025 14:28:00
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.649 | GP: 0.856 | Grad: 1377.908 | Expert Scores: -0.150 | Policy Scores: -0.202
# Prey     | ES-Reward: 0.003 | Wasserstein Loss: 3.965 | GP: 0.463 | Grad: 48.391 | Expert Scores: -0.197 | Policy Scores: -0.397
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 37/61] - Time: 15:22 - Estimated Finish: 05.12.2025 14:26:56
# Predator | ES-Reward: -0.001 | Wasserstein Loss: 7.661 | GP: 0.857 | Grad: 659.009 | Expert Scores: -0.150 | Policy Scores: -0.200
# Prey     | ES-Reward: -0.002 | Wasserstein Loss: 3.765 | GP: 0.441 | Grad: 76.271 | Expert Scores: -0.196 | Policy Scores: -0.403
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 38/61] - Time: 15:26 - Estimated Finish: 05.12.2025 14:28:34
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.674 | GP: 0.858 | Grad: 1708.934 | Expert Scores: -0.150 | Policy Scores: -0.203
# Prey     | ES-Reward: -0.008 | Wasserstein Loss: 3.587 | GP: 0.425 | Grad: 83.388 | Expert Scores: -0.199 | Policy Scores: -0.442
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 39/61] - Time: 15:22 - Estimated Finish: 05.12.2025 14:27:07
# Predator | ES-Reward: 0.002 | Wasserstein Loss: 7.645 | GP: 0.855 | Grad: 4187.702 | Expert Scores: -0.151 | Policy Scores: -0.204
# Prey     | ES-Reward: 0.020 | Wasserstein Loss: 3.510 | GP: 0.417 | Grad: 29.681 | Expert Scores: -0.206 | Policy Scores: -0.445
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 40/61] - Time: 15:18 - Estimated Finish: 05.12.2025 14:25:28
# Predator | ES-Reward: 0.001 | Wasserstein Loss: 7.673 | GP: 0.858 | Grad: 1291.228 | Expert Scores: -0.152 | Policy Scores: -0.200
# Prey     | ES-Reward: -0.003 | Wasserstein Loss: 3.446 | GP: 0.414 | Grad: 32.617 | Expert Scores: -0.196 | Policy Scores: -0.475
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 41/61] - Time: 15:22 - Estimated Finish: 05.12.2025 14:26:58
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.682 | GP: 0.858 | Grad: 2480.401 | Expert Scores: -0.152 | Policy Scores: -0.195
# Prey     | ES-Reward: -0.004 | Wasserstein Loss: 3.279 | GP: 0.394 | Grad: 25.306 | Expert Scores: -0.199 | Policy Scores: -0.462
#
# Checkpoint successfully saved!
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 42/61] - Time: 15:20 - Estimated Finish: 05.12.2025 14:26:23
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.683 | GP: 0.858 | Grad: 961.920 | Expert Scores: -0.153 | Policy Scores: -0.193
# Prey     | ES-Reward: -0.001 | Wasserstein Loss: 3.062 | GP: 0.370 | Grad: 38.568 | Expert Scores: -0.203 | Policy Scores: -0.472
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 43/61] - Time: 15:22 - Estimated Finish: 05.12.2025 14:27:05
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.700 | GP: 0.860 | Grad: 1483.189 | Expert Scores: -0.149 | Policy Scores: -0.190
# Prey     | ES-Reward: 0.011 | Wasserstein Loss: 3.048 | GP: 0.369 | Grad: 29.371 | Expert Scores: -0.195 | Policy Scores: -0.473
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 44/61] - Time: 15:20 - Estimated Finish: 05.12.2025 14:26:30
# Predator | ES-Reward: -0.001 | Wasserstein Loss: 7.687 | GP: 0.858 | Grad: 1705.192 | Expert Scores: -0.150 | Policy Scores: -0.189
# Prey     | ES-Reward: 0.006 | Wasserstein Loss: 2.998 | GP: 0.364 | Grad: 28.563 | Expert Scores: -0.204 | Policy Scores: -0.478
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 45/61] - Time: 15:22 - Estimated Finish: 05.12.2025 14:27:06
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.661 | GP: 0.855 | Grad: 2505.443 | Expert Scores: -0.152 | Policy Scores: -0.190
# Prey     | ES-Reward: -0.001 | Wasserstein Loss: 2.872 | GP: 0.350 | Grad: 69.383 | Expert Scores: -0.206 | Policy Scores: -0.487
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 46/61] - Time: 15:20 - Estimated Finish: 05.12.2025 14:26:34
# Predator | ES-Reward: -0.002 | Wasserstein Loss: 7.672 | GP: 0.857 | Grad: 2334.322 | Expert Scores: -0.151 | Policy Scores: -0.190
# Prey     | ES-Reward: 0.017 | Wasserstein Loss: 2.749 | GP: 0.337 | Grad: 34.389 | Expert Scores: -0.201 | Policy Scores: -0.486
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [DEBUG|ES] rewards_norm mean/std: 7424.96689803828 3695.3930944974436
#            grad norm: 161032.296875
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 47/61] - Time: 15:40 - Estimated Finish: 05.12.2025 14:31:25
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.658 | GP: 0.856 | Grad: 5060.094 | Expert Scores: -0.151 | Policy Scores: -0.196
# Prey     | ES-Reward: -0.004 | Wasserstein Loss: 2.734 | GP: 0.339 | Grad: 105.552 | Expert Scores: -0.206 | Policy Scores: -0.522
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 48/61] - Time: 15:16 - Estimated Finish: 05.12.2025 14:25:51
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.658 | GP: 0.856 | Grad: 3102.771 | Expert Scores: -0.152 | Policy Scores: -0.194
# Prey     | ES-Reward: 0.016 | Wasserstein Loss: 2.612 | GP: 0.323 | Grad: 59.291 | Expert Scores: -0.209 | Policy Scores: -0.502
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 49/61] - Time: 15:22 - Estimated Finish: 05.12.2025 14:27:11
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.661 | GP: 0.856 | Grad: 3798.432 | Expert Scores: -0.151 | Policy Scores: -0.197
# Prey     | ES-Reward: 0.016 | Wasserstein Loss: 2.317 | GP: 0.292 | Grad: 92.806 | Expert Scores: -0.212 | Policy Scores: -0.524
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 50/61] - Time: 15:27 - Estimated Finish: 05.12.2025 14:28:05
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.675 | GP: 0.858 | Grad: 6792.412 | Expert Scores: -0.148 | Policy Scores: -0.192
# Prey     | ES-Reward: 0.006 | Wasserstein Loss: 2.431 | GP: 0.304 | Grad: 41.785 | Expert Scores: -0.212 | Policy Scores: -0.517
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 51/61] - Time: 15:20 - Estimated Finish: 05.12.2025 14:26:57
# Predator | ES-Reward: -0.001 | Wasserstein Loss: 7.655 | GP: 0.855 | Grad: 17855.516 | Expert Scores: -0.151 | Policy Scores: -0.194
# Prey     | ES-Reward: 0.000 | Wasserstein Loss: 2.322 | GP: 0.294 | Grad: 21.162 | Expert Scores: -0.210 | Policy Scores: -0.535
#
# Checkpoint successfully saved!
#
# [DEBUG|ES] rewards_norm mean/std: 11327.630546889552 5748.228530921332
#            grad norm: 2070129.0
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 52/61] - Time: 15:20 - Estimated Finish: 05.12.2025 14:27:03
# Predator | ES-Reward: -0.001 | Wasserstein Loss: 7.678 | GP: 0.858 | Grad: 2530.867 | Expert Scores: -0.148 | Policy Scores: -0.195
# Prey     | ES-Reward: 0.016 | Wasserstein Loss: 2.265 | GP: 0.287 | Grad: 51.224 | Expert Scores: -0.210 | Policy Scores: -0.525
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 53/61] - Time: 15:19 - Estimated Finish: 05.12.2025 14:26:53
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.677 | GP: 0.857 | Grad: 6306.147 | Expert Scores: -0.150 | Policy Scores: -0.190
# Prey     | ES-Reward: 0.011 | Wasserstein Loss: 2.082 | GP: 0.268 | Grad: 120.609 | Expert Scores: -0.214 | Policy Scores: -0.543
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 54/61] - Time: 15:21 - Estimated Finish: 05.12.2025 14:27:11
# Predator | ES-Reward: 0.001 | Wasserstein Loss: 7.709 | GP: 0.860 | Grad: 4053.089 | Expert Scores: -0.151 | Policy Scores: -0.184
# Prey     | ES-Reward: 0.010 | Wasserstein Loss: 2.100 | GP: 0.266 | Grad: 115.579 | Expert Scores: -0.213 | Policy Scores: -0.505
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 55/61] - Time: 15:22 - Estimated Finish: 05.12.2025 14:27:15
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.691 | GP: 0.858 | Grad: 3523.178 | Expert Scores: -0.148 | Policy Scores: -0.183
# Prey     | ES-Reward: -0.002 | Wasserstein Loss: 1.983 | GP: 0.256 | Grad: 2204.418 | Expert Scores: -0.216 | Policy Scores: -0.535
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 56/61] - Time: 15:20 - Estimated Finish: 05.12.2025 14:27:04
# Predator | ES-Reward: 0.001 | Wasserstein Loss: 7.707 | GP: 0.860 | Grad: 29025.070 | Expert Scores: -0.149 | Policy Scores: -0.178
# Prey     | ES-Reward: -0.004 | Wasserstein Loss: 1.866 | GP: 0.242 | Grad: 23.585 | Expert Scores: -0.212 | Policy Scores: -0.524
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 57/61] - Time: 15:21 - Estimated Finish: 05.12.2025 14:27:08
# Predator | ES-Reward: 0.002 | Wasserstein Loss: 7.697 | GP: 0.858 | Grad: 3115.048 | Expert Scores: -0.150 | Policy Scores: -0.176
# Prey     | ES-Reward: -0.010 | Wasserstein Loss: 1.654 | GP: 0.224 | Grad: 33.411 | Expert Scores: -0.215 | Policy Scores: -0.578
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 58/61] - Time: 15:16 - Estimated Finish: 05.12.2025 14:26:48
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.646 | GP: 0.853 | Grad: 636.243 | Expert Scores: -0.151 | Policy Scores: -0.183
# Prey     | ES-Reward: 0.010 | Wasserstein Loss: 1.718 | GP: 0.233 | Grad: 110.371 | Expert Scores: -0.219 | Policy Scores: -0.595
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 59/61] - Time: 15:18 - Estimated Finish: 05.12.2025 14:26:55
# Predator | ES-Reward: -0.000 | Wasserstein Loss: 7.629 | GP: 0.852 | Grad: 5281.498 | Expert Scores: -0.149 | Policy Scores: -0.186
# Prey     | ES-Reward: 0.008 | Wasserstein Loss: 1.581 | GP: 0.219 | Grad: 540.466 | Expert Scores: -0.220 | Policy Scores: -0.610
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 60/61] - Time: 15:22 - Estimated Finish: 05.12.2025 14:27:03
# Predator | ES-Reward: 0.000 | Wasserstein Loss: 7.694 | GP: 0.859 | Grad: 3251.285 | Expert Scores: -0.148 | Policy Scores: -0.184
# Prey     | ES-Reward: -0.013 | Wasserstein Loss: 1.608 | GP: 0.219 | Grad: 364.819 | Expert Scores: -0.222 | Policy Scores: -0.583
#
# [PREDATOR] Pairwise Interaction Network updated! [1/1]
# [PREDATOR] Attention Network updated! [1/1]
# [PREY] Pairwise Interaction Network updated! [1/1]
# [PREY] Attention Network updated! [1/1]
# [PREY] Predator Pairwise Interaction Network updated! [1/1]
#
# [Generation 61/61] - Time: 15:18 - Estimated Finish: 05.12.2025 14:26:59
# Predator | ES-Reward: -0.001 | Wasserstein Loss: 7.670 | GP: 0.857 | Grad: 25254.525 | Expert Scores: -0.148 | Policy Scores: -0.187
# Prey     | ES-Reward: 0.024 | Wasserstein Loss: 1.598 | GP: 0.219 | Grad: 220.380 | Expert Scores: -0.220 | Policy Scores: -0.596
#
# Checkpoint successfully saved!
#
# Models successfully saved!
# Training done!
