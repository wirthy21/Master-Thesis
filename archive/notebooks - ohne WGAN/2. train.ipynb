# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

import pickle
import datetime
from utils.es_utils import *
from utils.env_utils import *
from utils.train_utils import *
from marl_aquarium import aquarium_v0
from models.Buffer import Buffer, Pool
from models.Generator import GeneratorPolicy
from models.Discriminator import Discriminator

# %%
"""
Multi-Agent Imitation lernt nur so schnell wie das schwächste Glied.

ToDo's
- Wasserstein Loss
- Händisch Predator Aktion labeln

Falls Training keine Fortschritte:
    - Discriminator Prey-Input (32, 32, 5)?
    - CUDA-Toolkit installieren, damit Modell auf GPU
    - Struktur Netzwerk anpassen (Layer, Batch Normalization, Dropout)
    - PPO statt ES
    - WGAN Loss
    - Abwechselndes Training von Modulen und Policies
"""
# Out:
# "\nMulti-Agent Imitation lernt nur so schnell wie das schwächste Glied.\n\nToDo's\n- Tuning bauen (Ray)\n- Händisch Predator Aktion labeln\n\nFalls Training keine Fortschritte:\n    - Discriminator Prey-Input (32, 32, 5)?\n    - CUDA-Toolkit installieren, damit Modell auf GPU\n    - Struktur Netzwerk anpassen (Layer, Batch Normalization, Dropout)\n    - PPO statt ES\n    - WGAN Loss\n    - Abwechselndes Training von Modulen und Policies\n"

# %%
# Hyperparameters

#Environment
pred_count = 1
prey_count = 32 
action_count = 360
use_walls = True

# generated_trajectories
gt_gen_episodes = 10
gt_clip_length = 30

# Buffer
pred_buffer_size = 800
prey_buffer_size = 24000

# Training
pred_batch_size = 128           #     32, 512
prey_batch_size = 1024          #    256, 1024
num_generations = 200           #     80, 200
patience = 15                   #     20,   
window_size = 10                #     10,
min_slope = 0
gen_dis_ratio = 1               #      7, 5, 1

# ES-Pertrubation
num_perturbations = 40          #     32, 40
pert_clip_length = 15           #     10, 30, 100, 15
sigma = 0.25                    #    0.1, 0.2, 0.25   
gamma = 0.9997                  # 0.9997,
lr_pred_policy = 0.03           #   0.01, 0.02, 0.03
lr_prey_policy = 0.03           #   0.05, 0.03

# RMSprop
lr_pred_dis =  0.0005           #  0.001, 0.0005, 0.0001, 0.0005,
lr_prey_dis = 0.0005            #  0.001, 0.0005, 0.0001, 0.0005,
alpha=0.99                      #   0.99,
eps_dis=1e-08                   #  1e-08,
lambda_gp_pred = 5              #     10, 5
lambda_gp_prey = 5              #     10, 5
label_smoothing = True
smooth = 0.1

# %%
# Video Data
video = "video_8min"
num_frames=1
total_detections=33

# create training folder
path = r"..\data\training"
timestamp = datetime.datetime.now().strftime("%d.%m.%Y_%H.%M")
folder_name = f"Training - {timestamp}"
save_dir = os.path.join(path, folder_name)
os.makedirs(save_dir, exist_ok=True)

# Video folder
raw_video_folder = rf'..\data\raw\videos'
video_path = raw_video_folder + "\\" + video + ".mp4"

# Expert Data
data_path = rf"..\data\processed\{video}\expert_tensors"
processed_video_folder = rf'..\data\processed\{video}'
ftw_path = os.path.join(processed_video_folder, "full_track_windows", f"full_track_windows_{total_detections}.pkl")

with open(ftw_path, "rb") as f:
    full_track_windows = pickle.load(f)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

pred_policy = GeneratorPolicy().to(device)
pred_policy.set_parameters(init=True)

prey_policy = GeneratorPolicy().to(device)
prey_policy.set_parameters(init=True)

pred_discriminator = Discriminator().to(device)
pred_discriminator.set_parameters(init=True)
optim_dis_pred = torch.optim.RMSprop(pred_discriminator.parameters(), lr=lr_pred_dis, alpha=alpha, eps=eps_dis)

prey_discriminator = Discriminator().to(device)
prey_discriminator.set_parameters(init=True)
optim_dis_prey = torch.optim.RMSprop(prey_discriminator.parameters(), lr=lr_prey_dis, alpha=alpha, eps=eps_dis)

expert_buffer = Buffer(pred_max_length=pred_buffer_size, prey_max_length=prey_buffer_size, device=device)
generative_buffer = Buffer(pred_max_length=pred_buffer_size, prey_max_length=prey_buffer_size, device=device)

start_frame_pool = Pool(max_length=1000, device=device)
start_frame_pool.generate_startframes(video_path, full_track_windows)

early_stopper_pred = EarlyStoppingWindow(patience=patience, window_size=window_size, min_slope=min_slope)
early_stopper_prey = EarlyStoppingWindow(patience=patience, window_size=window_size, min_slope=min_slope)

# %%
# Load Expert Data from local storage
print("Expert Buffer is empty, load data...")
expert_buffer.add_expert(data_path, window_size=1, detections=33)
len_exp_pred, len_exp_prey = expert_buffer.lengths()

print("Storage of Predator Expert Buffer: ", len_exp_pred)
print("Storage of Prey Expert Buffer: ", len_exp_prey, "\n")
# Out:
# Expert Buffer is empty, load data...
# Storage of Predator Expert Buffer:  742
# Storage of Prey Expert Buffer:  23744

# %%
# Pretrain Policies with Expert Data
print("Pretraining Policies with Behavioral Cloning on Expert Data...\n")
pred_policy = pretrain_policy(pred_policy, expert_buffer, role='predator', pred_bs=512, epochs=120, lr=1e-3, save_dir=save_dir)
prey_policy = pretrain_policy(prey_policy, expert_buffer, role='prey', prey_bs=1024, epochs=220, lr=1e-3, save_dir=save_dir)
# Out:
# Pretraining Policies with Behavioral Cloning on Expert Data...

# %%
# Generate Trajectories for Generative Buffer
print("Generative Buffer is empty, generating data...")
generate_trajectories(buffer=generative_buffer, start_frame_pool=start_frame_pool,
                        pred_count=pred_count, prey_count=prey_count, action_count=action_count, 
                        pred_policy=pred_policy, prey_policy=prey_policy, 
                        clip_length=gt_clip_length, num_generative_episodes=gt_gen_episodes,
                        use_walls=True)

len_gen_pred, len_gen_prey = generative_buffer.lengths()
print("Storage of Predator Generative Buffer: ", len_gen_pred)
print("Storage of Prey Generative Buffer: ", len_gen_prey)
# Out:
# Generative Buffer is empty, generating data...
# Storage of Predator Generative Buffer:  300
# Storage of Prey Generative Buffer:  9600

# %%
dis_metrics_pred = []
dis_metrics_prey = []

es_metrics_pred = []
es_metrics_prey = []

for generation in range(num_generations):
    start_time = time.time()
    
    # Sample traj from expert and generative buffer
    expert_pred_batch, expert_prey_batch = expert_buffer.sample(pred_batch_size, prey_batch_size)
    policy_pred_batch, policy_prey_batch = generative_buffer.sample(pred_batch_size, prey_batch_size)

    # Predator discriminator update
    dis_metric_pred = pred_discriminator.update(expert_pred_batch, policy_pred_batch, optim_dis_pred, lambda_gp_pred, label_smoothing, smooth)
    dis_metrics_pred.append(dis_metric_pred)
                                     
    # Prey discriminator update
    dis_metric_prey = prey_discriminator.update(expert_prey_batch, policy_prey_batch, optim_dis_prey, lambda_gp_prey, label_smoothing, smooth)
    dis_metrics_prey.append(dis_metric_prey)

    for i in range(gen_dis_ratio):
        pred_stats = pred_policy.update("predator", "pairwise",
                                        pred_count, prey_count, action_count,
                                        pred_policy, prey_policy,
                                        pred_discriminator, prey_discriminator,
                                        num_perturbations, generation,
                                        lr_pred_policy, lr_prey_policy,
                                        sigma, gamma, clip_length=pert_clip_length,
                                        use_walls=use_walls, start_frame_pool=start_frame_pool)
        

        pred_stats += pred_policy.update("predator", "attention",
                                        pred_count, prey_count, action_count,
                                        pred_policy, prey_policy,
                                        pred_discriminator, prey_discriminator,
                                        num_perturbations, generation,
                                        lr_pred_policy, lr_prey_policy,
                                        sigma, gamma, clip_length=pert_clip_length,
                                        use_walls=use_walls, start_frame_pool=start_frame_pool)
        es_metrics_pred.append(pred_stats)


        prey_stats = prey_policy.update("prey", "pairwise",
                                        pred_count, prey_count, action_count,
                                        pred_policy, prey_policy,
                                        pred_discriminator, prey_discriminator,
                                        num_perturbations, generation,
                                        lr_pred_policy, lr_prey_policy,
                                        sigma, gamma, clip_length=pert_clip_length,
                                        use_walls=use_walls, start_frame_pool=start_frame_pool)
        
        prey_stats += prey_policy.update("prey", "attention",
                                        pred_count, prey_count, action_count,
                                        pred_policy, prey_policy,
                                        pred_discriminator, prey_discriminator,
                                        num_perturbations, generation,
                                        lr_pred_policy, lr_prey_policy,
                                        sigma, gamma, clip_length=pert_clip_length,
                                        use_walls=use_walls, start_frame_pool=start_frame_pool)
        es_metrics_prey.append(prey_stats)

        # Generate new trajectories with updated policies
        generate_trajectories(buffer=generative_buffer, start_frame_pool=start_frame_pool,
                                pred_count=pred_count, prey_count=prey_count, action_count=action_count, 
                                pred_policy=pred_policy, prey_policy=prey_policy, 
                                clip_length=gt_clip_length, num_generative_episodes=gt_gen_episodes,
                                use_walls=use_walls)

    # also reduce globally
    sigma *= gamma
    lr_pred_policy *= gamma
    lr_prey_policy *= gamma

    last_epoch_duration = time.time() - start_time
    estimated_time, epoch_time = remaining_time(num_generations, last_epoch_duration, current_generation=generation)

    avg_es_pred = np.mean([m['avg_reward_diff'] for m in pred_stats])
    avg_es_prey = np.mean([m['avg_reward_diff'] for m in prey_stats])
        
    print(f"[Generation {generation+1}/{num_generations}] - Time: {epoch_time} - Estimated Finish: {estimated_time}" )
    print(f"Predator | Avg. ES-Reward: {avg_es_pred:.4f} | DisLoss: {dis_metric_pred[0]:.4f} | Expert Scores: {dis_metric_pred[2]:.4f} | Policy Scores: {dis_metric_pred[3]:.4f}")
    print(f"Prey     | Avg. ES-Reward: {avg_es_prey:.4f} | DisLoss: {dis_metric_prey[0]:.4f} | Expert Scores: {dis_metric_prey[2]:.4f} | Policy Scores: {dis_metric_prey[3]:.4f}\n")

#    if early_stopper_pred(avg_es_pred, "predator") or early_stopper_prey(avg_es_prey, "prey"):
#        break


    if generation % 50 == 0:
        save_checkpoint(save_dir, generation,
                        pred_policy, prey_policy,
                        pred_discriminator, prey_discriminator,
                        optim_dis_pred, optim_dis_prey,
                        expert_buffer, generative_buffer,
                        dis_metrics_pred, dis_metrics_prey,
                        es_metrics_pred, es_metrics_prey)


# Save models
save_models(save_dir,
            pred_policy, prey_policy,
            pred_discriminator, prey_discriminator,
            optim_dis_pred, optim_dis_prey,
            expert_buffer, generative_buffer,
            dis_metrics_pred, dis_metrics_prey,
            es_metrics_pred, es_metrics_prey)
# Out:
# [Generation 1/200] - Time: 4:55 - Estimated Finish: 26.07.2025 03:06:53
# Predator | Avg. ES-Reward: 0.0192 | DisLoss: 6.2049 | Expert Scores: 0.5183 | Policy Scores: 0.5286
# Prey     | Avg. ES-Reward: 0.0830 | DisLoss: 6.1002 | Expert Scores: 0.4781 | Policy Scores: 0.4610
#
# Checkpoint successfully saved!
#
# [Generation 2/200] - Time: 4:40 - Estimated Finish: 26.07.2025 02:16:53
# Predator | Avg. ES-Reward: -0.0236 | DisLoss: 6.0806 | Expert Scores: 0.5271 | Policy Scores: 0.4955
# Prey     | Avg. ES-Reward: -0.0477 | DisLoss: 5.8654 | Expert Scores: 0.4773 | Policy Scores: 0.4156
#
# [Generation 3/200] - Time: 4:57 - Estimated Finish: 26.07.2025 03:13:39
# Predator | Avg. ES-Reward: 0.1401 | DisLoss: 5.8806 | Expert Scores: 0.5382 | Policy Scores: 0.4662
# Prey     | Avg. ES-Reward: 0.1406 | DisLoss: 5.6549 | Expert Scores: 0.4788 | Policy Scores: 0.4143
#
# [Generation 4/200] - Time: 4:53 - Estimated Finish: 26.07.2025 02:59:29
# Predator | Avg. ES-Reward: 0.1894 | DisLoss: 5.6372 | Expert Scores: 0.5504 | Policy Scores: 0.4360
# Prey     | Avg. ES-Reward: 0.1371 | DisLoss: 5.3750 | Expert Scores: 0.4883 | Policy Scores: 0.3882
#
# [Generation 5/200] - Time: 4:30 - Estimated Finish: 26.07.2025 01:45:13
# Predator | Avg. ES-Reward: 0.3094 | DisLoss: 5.4007 | Expert Scores: 0.5623 | Policy Scores: 0.4256
# Prey     | Avg. ES-Reward: 0.1303 | DisLoss: 5.1194 | Expert Scores: 0.4944 | Policy Scores: 0.2947
#
# [Generation 6/200] - Time: 4:36 - Estimated Finish: 26.07.2025 02:05:11
# Predator | Avg. ES-Reward: 0.2408 | DisLoss: 5.1685 | Expert Scores: 0.5764 | Policy Scores: 0.3952
# Prey     | Avg. ES-Reward: 0.2432 | DisLoss: 4.8192 | Expert Scores: 0.5063 | Policy Scores: 0.2617
#
# [Generation 7/200] - Time: 4:41 - Estimated Finish: 26.07.2025 02:19:29
# Predator | Avg. ES-Reward: 0.2646 | DisLoss: 4.7675 | Expert Scores: 0.5906 | Policy Scores: 0.3568
# Prey     | Avg. ES-Reward: 0.3055 | DisLoss: 4.4939 | Expert Scores: 0.5224 | Policy Scores: 0.2559
#
# [Generation 8/200] - Time: 4:30 - Estimated Finish: 26.07.2025 01:45:06
# Predator | Avg. ES-Reward: 0.3623 | DisLoss: 4.4654 | Expert Scores: 0.6048 | Policy Scores: 0.3096
# Prey     | Avg. ES-Reward: 0.4153 | DisLoss: 4.1375 | Expert Scores: 0.5393 | Policy Scores: 0.2803
#
# [Generation 9/200] - Time: 4:30 - Estimated Finish: 26.07.2025 01:46:05
# Predator | Avg. ES-Reward: 0.3631 | DisLoss: 4.2354 | Expert Scores: 0.5991 | Policy Scores: 0.2823
# Prey     | Avg. ES-Reward: 0.1933 | DisLoss: 3.9188 | Expert Scores: 0.5509 | Policy Scores: 0.3815
#
# [Generation 10/200] - Time: 4:20 - Estimated Finish: 26.07.2025 01:13:01
# Predator | Avg. ES-Reward: 0.4222 | DisLoss: 4.0237 | Expert Scores: 0.6187 | Policy Scores: 0.2606
# Prey     | Avg. ES-Reward: 0.4007 | DisLoss: 3.6984 | Expert Scores: 0.5506 | Policy Scores: 0.1919
#
# [Generation 11/200] - Time: 4:23 - Estimated Finish: 26.07.2025 01:23:57
# Predator | Avg. ES-Reward: 0.3309 | DisLoss: 3.8316 | Expert Scores: 0.6348 | Policy Scores: 0.3105
# Prey     | Avg. ES-Reward: 0.3189 | DisLoss: 3.6780 | Expert Scores: 0.5669 | Policy Scores: 0.4228
#
# [Generation 12/200] - Time: 4:24 - Estimated Finish: 26.07.2025 01:25:25
# Predator | Avg. ES-Reward: 0.3827 | DisLoss: 3.7802 | Expert Scores: 0.6376 | Policy Scores: 0.2576
# Prey     | Avg. ES-Reward: 0.2874 | DisLoss: 3.2868 | Expert Scores: 0.5713 | Policy Scores: 0.2348
#
# [Generation 13/200] - Time: 4:24 - Estimated Finish: 26.07.2025 01:26:47
# Predator | Avg. ES-Reward: 0.3325 | DisLoss: 3.7845 | Expert Scores: 0.6609 | Policy Scores: 0.3606
# Prey     | Avg. ES-Reward: 0.4196 | DisLoss: 3.2513 | Expert Scores: 0.5817 | Policy Scores: 0.4046
#
# [Generation 14/200] - Time: 4:47 - Estimated Finish: 26.07.2025 02:36:13
# Predator | Avg. ES-Reward: 0.2601 | DisLoss: 3.6218 | Expert Scores: 0.6553 | Policy Scores: 0.2344
# Prey     | Avg. ES-Reward: 0.5436 | DisLoss: 2.9850 | Expert Scores: 0.5844 | Policy Scores: 0.2663
#
# [Generation 15/200] - Time: 4:34 - Estimated Finish: 26.07.2025 01:57:10
# Predator | Avg. ES-Reward: 0.2940 | DisLoss: 3.7973 | Expert Scores: 0.6702 | Policy Scores: 0.3803
# Prey     | Avg. ES-Reward: 0.3270 | DisLoss: 3.0043 | Expert Scores: 0.6014 | Policy Scores: 0.3394
#
# [Generation 16/200] - Time: 4:33 - Estimated Finish: 26.07.2025 01:54:23
# Predator | Avg. ES-Reward: 0.3093 | DisLoss: 3.7085 | Expert Scores: 0.6677 | Policy Scores: 0.2462
# Prey     | Avg. ES-Reward: 0.4630 | DisLoss: 2.8442 | Expert Scores: 0.6034 | Policy Scores: 0.2890
#
# [Generation 17/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:48:37
# Predator | Avg. ES-Reward: 0.2311 | DisLoss: 3.6296 | Expert Scores: 0.6939 | Policy Scores: 0.3593
# Prey     | Avg. ES-Reward: 0.3533 | DisLoss: 2.8231 | Expert Scores: 0.6163 | Policy Scores: 0.3336
#
# [Generation 18/200] - Time: 4:30 - Estimated Finish: 26.07.2025 01:46:10
# Predator | Avg. ES-Reward: 0.2590 | DisLoss: 3.5105 | Expert Scores: 0.6827 | Policy Scores: 0.2419
# Prey     | Avg. ES-Reward: 0.1838 | DisLoss: 2.7377 | Expert Scores: 0.6247 | Policy Scores: 0.3209
#
# [Generation 19/200] - Time: 4:35 - Estimated Finish: 26.07.2025 01:59:56
# Predator | Avg. ES-Reward: 0.3593 | DisLoss: 3.4868 | Expert Scores: 0.6986 | Policy Scores: 0.3162
# Prey     | Avg. ES-Reward: 0.3720 | DisLoss: 2.7259 | Expert Scores: 0.6349 | Policy Scores: 0.2901
#
# [Generation 20/200] - Time: 4:44 - Estimated Finish: 26.07.2025 02:27:50
# Predator | Avg. ES-Reward: 0.3238 | DisLoss: 3.3428 | Expert Scores: 0.7088 | Policy Scores: 0.2973
# Prey     | Avg. ES-Reward: 0.2074 | DisLoss: 2.4831 | Expert Scores: 0.6343 | Policy Scores: 0.2589
#
# [Generation 21/200] - Time: 4:20 - Estimated Finish: 26.07.2025 01:14:56
# Predator | Avg. ES-Reward: 0.3108 | DisLoss: 3.2606 | Expert Scores: 0.7220 | Policy Scores: 0.3014
# Prey     | Avg. ES-Reward: 0.4010 | DisLoss: 2.3571 | Expert Scores: 0.6460 | Policy Scores: 0.3871
#
# [Generation 22/200] - Time: 4:30 - Estimated Finish: 26.07.2025 01:44:52
# Predator | Avg. ES-Reward: 0.3565 | DisLoss: 3.2135 | Expert Scores: 0.7330 | Policy Scores: 0.3173
# Prey     | Avg. ES-Reward: 0.3292 | DisLoss: 2.0888 | Expert Scores: 0.6243 | Policy Scores: 0.2342
#
# [Generation 23/200] - Time: 4:24 - Estimated Finish: 26.07.2025 01:26:37
# Predator | Avg. ES-Reward: 0.3184 | DisLoss: 3.0599 | Expert Scores: 0.7389 | Policy Scores: 0.2902
# Prey     | Avg. ES-Reward: 0.5025 | DisLoss: 2.1491 | Expert Scores: 0.6460 | Policy Scores: 0.5235
#
# [Generation 24/200] - Time: 4:33 - Estimated Finish: 26.07.2025 01:54:24
# Predator | Avg. ES-Reward: 0.3733 | DisLoss: 3.0397 | Expert Scores: 0.7348 | Policy Scores: 0.3198
# Prey     | Avg. ES-Reward: 0.2353 | DisLoss: 2.2449 | Expert Scores: 0.6138 | Policy Scores: 0.1526
#
# [Generation 25/200] - Time: 4:40 - Estimated Finish: 26.07.2025 02:15:23
# Predator | Avg. ES-Reward: 0.3915 | DisLoss: 2.9589 | Expert Scores: 0.7332 | Policy Scores: 0.2642
# Prey     | Avg. ES-Reward: 0.1644 | DisLoss: 1.9740 | Expert Scores: 0.6451 | Policy Scores: 0.3239
#
# [Generation 26/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:47:22
# Predator | Avg. ES-Reward: 0.3816 | DisLoss: 2.9970 | Expert Scores: 0.7343 | Policy Scores: 0.3246
# Prey     | Avg. ES-Reward: 0.2747 | DisLoss: 2.0252 | Expert Scores: 0.6400 | Policy Scores: 0.2850
#
# [Generation 27/200] - Time: 4:27 - Estimated Finish: 26.07.2025 01:37:45
# Predator | Avg. ES-Reward: 0.3592 | DisLoss: 2.8263 | Expert Scores: 0.7470 | Policy Scores: 0.3037
# Prey     | Avg. ES-Reward: 0.2787 | DisLoss: 2.1535 | Expert Scores: 0.6504 | Policy Scores: 0.3195
#
# [Generation 28/200] - Time: 4:27 - Estimated Finish: 26.07.2025 01:36:30
# Predator | Avg. ES-Reward: 0.3657 | DisLoss: 2.8982 | Expert Scores: 0.7378 | Policy Scores: 0.3439
# Prey     | Avg. ES-Reward: 0.2513 | DisLoss: 2.4758 | Expert Scores: 0.6519 | Policy Scores: 0.3858
#
# [Generation 29/200] - Time: 4:25 - Estimated Finish: 26.07.2025 01:31:34
# Predator | Avg. ES-Reward: 0.3200 | DisLoss: 2.8386 | Expert Scores: 0.7308 | Policy Scores: 0.2575
# Prey     | Avg. ES-Reward: 0.3168 | DisLoss: 2.6747 | Expert Scores: 0.6555 | Policy Scores: 0.4804
#
# [Generation 30/200] - Time: 4:26 - Estimated Finish: 26.07.2025 01:34:14
# Predator | Avg. ES-Reward: 0.3173 | DisLoss: 2.9683 | Expert Scores: 0.7374 | Policy Scores: 0.3575
# Prey     | Avg. ES-Reward: 0.4766 | DisLoss: 2.4178 | Expert Scores: 0.6411 | Policy Scores: 0.4151
#
# [Generation 31/200] - Time: 4:32 - Estimated Finish: 26.07.2025 01:51:12
# Predator | Avg. ES-Reward: 0.3463 | DisLoss: 2.7538 | Expert Scores: 0.7412 | Policy Scores: 0.2853
# Prey     | Avg. ES-Reward: 0.4103 | DisLoss: 2.2544 | Expert Scores: 0.6357 | Policy Scores: 0.3249
#
# [Generation 32/200] - Time: 4:27 - Estimated Finish: 26.07.2025 01:37:09
# Predator | Avg. ES-Reward: 0.4218 | DisLoss: 2.8158 | Expert Scores: 0.7603 | Policy Scores: 0.3708
# Prey     | Avg. ES-Reward: 0.7390 | DisLoss: 2.1674 | Expert Scores: 0.6424 | Policy Scores: 0.2960
#
# [Generation 33/200] - Time: 4:28 - Estimated Finish: 26.07.2025 01:39:46
# Predator | Avg. ES-Reward: 0.3415 | DisLoss: 2.6958 | Expert Scores: 0.7468 | Policy Scores: 0.2394
# Prey     | Avg. ES-Reward: 0.2608 | DisLoss: 1.9310 | Expert Scores: 0.6375 | Policy Scores: 0.3356
#
# [Generation 34/200] - Time: 4:33 - Estimated Finish: 26.07.2025 01:52:34
# Predator | Avg. ES-Reward: 0.3816 | DisLoss: 2.8496 | Expert Scores: 0.7636 | Policy Scores: 0.4081
# Prey     | Avg. ES-Reward: 0.3726 | DisLoss: 1.6563 | Expert Scores: 0.6425 | Policy Scores: 0.3839
#
# [Generation 35/200] - Time: 4:41 - Estimated Finish: 26.07.2025 02:15:16
# Predator | Avg. ES-Reward: 0.3440 | DisLoss: 2.7943 | Expert Scores: 0.7355 | Policy Scores: 0.2839
# Prey     | Avg. ES-Reward: 0.3863 | DisLoss: 1.5244 | Expert Scores: 0.6414 | Policy Scores: 0.3817
#
# [Generation 36/200] - Time: 4:44 - Estimated Finish: 26.07.2025 02:24:15
# Predator | Avg. ES-Reward: 0.3306 | DisLoss: 2.7411 | Expert Scores: 0.7581 | Policy Scores: 0.3248
# Prey     | Avg. ES-Reward: 0.2431 | DisLoss: 1.5501 | Expert Scores: 0.6281 | Policy Scores: 0.2928
#
# [Generation 37/200] - Time: 4:35 - Estimated Finish: 26.07.2025 01:59:44
# Predator | Avg. ES-Reward: 0.3819 | DisLoss: 2.6943 | Expert Scores: 0.7649 | Policy Scores: 0.3073
# Prey     | Avg. ES-Reward: 0.2745 | DisLoss: 1.5499 | Expert Scores: 0.6334 | Policy Scores: 0.3324
#
# [Generation 38/200] - Time: 4:33 - Estimated Finish: 26.07.2025 01:52:22
# Predator | Avg. ES-Reward: 0.3528 | DisLoss: 2.7053 | Expert Scores: 0.7628 | Policy Scores: 0.3745
# Prey     | Avg. ES-Reward: 0.2298 | DisLoss: 1.5229 | Expert Scores: 0.6377 | Policy Scores: 0.3132
#
# [Generation 39/200] - Time: 4:36 - Estimated Finish: 26.07.2025 02:03:03
# Predator | Avg. ES-Reward: 0.4008 | DisLoss: 2.5307 | Expert Scores: 0.7650 | Policy Scores: 0.2947
# Prey     | Avg. ES-Reward: 0.2961 | DisLoss: 1.5271 | Expert Scores: 0.6439 | Policy Scores: 0.3443
#
# [Generation 40/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:49:12
# Predator | Avg. ES-Reward: 0.4095 | DisLoss: 2.6330 | Expert Scores: 0.7625 | Policy Scores: 0.3705
# Prey     | Avg. ES-Reward: 0.1770 | DisLoss: 1.5411 | Expert Scores: 0.6481 | Policy Scores: 0.3055
#
# [Generation 41/200] - Time: 4:25 - Estimated Finish: 26.07.2025 01:32:16
# Predator | Avg. ES-Reward: 0.4519 | DisLoss: 2.3702 | Expert Scores: 0.7603 | Policy Scores: 0.3086
# Prey     | Avg. ES-Reward: 0.2570 | DisLoss: 1.5349 | Expert Scores: 0.6480 | Policy Scores: 0.2858
#
# [Generation 42/200] - Time: 4:43 - Estimated Finish: 26.07.2025 02:19:18
# Predator | Avg. ES-Reward: 0.4083 | DisLoss: 2.3500 | Expert Scores: 0.7791 | Policy Scores: 0.3134
# Prey     | Avg. ES-Reward: 0.2383 | DisLoss: 1.6544 | Expert Scores: 0.6583 | Policy Scores: 0.3064
#
# [Generation 43/200] - Time: 4:27 - Estimated Finish: 26.07.2025 01:38:27
# Predator | Avg. ES-Reward: 0.4275 | DisLoss: 2.3673 | Expert Scores: 0.7708 | Policy Scores: 0.3301
# Prey     | Avg. ES-Reward: 0.1491 | DisLoss: 1.7806 | Expert Scores: 0.6624 | Policy Scores: 0.2936
#
# [Generation 44/200] - Time: 4:35 - Estimated Finish: 26.07.2025 01:58:12
# Predator | Avg. ES-Reward: 0.3862 | DisLoss: 2.3625 | Expert Scores: 0.7605 | Policy Scores: 0.2906
# Prey     | Avg. ES-Reward: 0.3953 | DisLoss: 1.8353 | Expert Scores: 0.6649 | Policy Scores: 0.3306
#
# [Generation 45/200] - Time: 4:36 - Estimated Finish: 26.07.2025 02:02:19
# Predator | Avg. ES-Reward: 0.4073 | DisLoss: 2.3630 | Expert Scores: 0.7833 | Policy Scores: 0.3593
# Prey     | Avg. ES-Reward: 0.1916 | DisLoss: 1.9007 | Expert Scores: 0.6715 | Policy Scores: 0.3194
#
# [Generation 46/200] - Time: 4:33 - Estimated Finish: 26.07.2025 01:53:24
# Predator | Avg. ES-Reward: 0.4043 | DisLoss: 2.2454 | Expert Scores: 0.7791 | Policy Scores: 0.2886
# Prey     | Avg. ES-Reward: 0.4229 | DisLoss: 1.9388 | Expert Scores: 0.6754 | Policy Scores: 0.3456
#
# [Generation 47/200] - Time: 4:35 - Estimated Finish: 26.07.2025 01:58:16
# Predator | Avg. ES-Reward: 0.4124 | DisLoss: 2.3278 | Expert Scores: 0.7723 | Policy Scores: 0.3367
# Prey     | Avg. ES-Reward: 0.3851 | DisLoss: 1.9808 | Expert Scores: 0.6716 | Policy Scores: 0.3556
#
# [Generation 48/200] - Time: 4:30 - Estimated Finish: 26.07.2025 01:46:44
# Predator | Avg. ES-Reward: 0.4236 | DisLoss: 2.3037 | Expert Scores: 0.7778 | Policy Scores: 0.3541
# Prey     | Avg. ES-Reward: 0.3689 | DisLoss: 1.9684 | Expert Scores: 0.6745 | Policy Scores: 0.3655
#
# [Generation 49/200] - Time: 4:27 - Estimated Finish: 26.07.2025 01:39:15
# Predator | Avg. ES-Reward: 0.3855 | DisLoss: 2.1761 | Expert Scores: 0.7771 | Policy Scores: 0.2930
# Prey     | Avg. ES-Reward: 0.3543 | DisLoss: 1.9455 | Expert Scores: 0.6645 | Policy Scores: 0.3524
#
# [Generation 50/200] - Time: 4:37 - Estimated Finish: 26.07.2025 02:04:04
# Predator | Avg. ES-Reward: 0.3624 | DisLoss: 2.2420 | Expert Scores: 0.7649 | Policy Scores: 0.3588
# Prey     | Avg. ES-Reward: 0.1785 | DisLoss: 1.7847 | Expert Scores: 0.6715 | Policy Scores: 0.3317
#
# [Generation 51/200] - Time: 4:37 - Estimated Finish: 26.07.2025 02:03:15
# Predator | Avg. ES-Reward: 0.3852 | DisLoss: 2.1230 | Expert Scores: 0.7671 | Policy Scores: 0.2911
# Prey     | Avg. ES-Reward: 0.4711 | DisLoss: 1.6210 | Expert Scores: 0.6651 | Policy Scores: 0.3336
#
# Checkpoint successfully saved!
#
# [Generation 52/200] - Time: 4:35 - Estimated Finish: 26.07.2025 01:57:42
# Predator | Avg. ES-Reward: 0.3617 | DisLoss: 2.3283 | Expert Scores: 0.7689 | Policy Scores: 0.3486
# Prey     | Avg. ES-Reward: 0.3285 | DisLoss: 1.5754 | Expert Scores: 0.6711 | Policy Scores: 0.4400
#
# [Generation 53/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:50:03
# Predator | Avg. ES-Reward: 0.3709 | DisLoss: 2.0950 | Expert Scores: 0.7793 | Policy Scores: 0.3324
# Prey     | Avg. ES-Reward: 0.4039 | DisLoss: 1.3383 | Expert Scores: 0.6583 | Policy Scores: 0.3408
#
# [Generation 54/200] - Time: 4:39 - Estimated Finish: 26.07.2025 02:08:38
# Predator | Avg. ES-Reward: 0.4030 | DisLoss: 2.0826 | Expert Scores: 0.7732 | Policy Scores: 0.3101
# Prey     | Avg. ES-Reward: 0.3705 | DisLoss: 1.4276 | Expert Scores: 0.6589 | Policy Scores: 0.2847
#
# [Generation 55/200] - Time: 4:22 - Estimated Finish: 26.07.2025 01:26:22
# Predator | Avg. ES-Reward: 0.4374 | DisLoss: 2.0466 | Expert Scores: 0.7840 | Policy Scores: 0.3277
# Prey     | Avg. ES-Reward: 0.0600 | DisLoss: 1.6302 | Expert Scores: 0.6653 | Policy Scores: 0.2863
#
# [Generation 56/200] - Time: 4:35 - Estimated Finish: 26.07.2025 01:59:34
# Predator | Avg. ES-Reward: 0.4113 | DisLoss: 2.0789 | Expert Scores: 0.7747 | Policy Scores: 0.3269
# Prey     | Avg. ES-Reward: 0.3233 | DisLoss: 1.7941 | Expert Scores: 0.6641 | Policy Scores: 0.3391
#
# [Generation 57/200] - Time: 4:36 - Estimated Finish: 26.07.2025 01:59:45
# Predator | Avg. ES-Reward: 0.4088 | DisLoss: 2.0331 | Expert Scores: 0.7572 | Policy Scores: 0.3227
# Prey     | Avg. ES-Reward: 0.2997 | DisLoss: 1.8032 | Expert Scores: 0.6697 | Policy Scores: 0.4015
#
# [Generation 58/200] - Time: 4:21 - Estimated Finish: 26.07.2025 01:25:38
# Predator | Avg. ES-Reward: 0.3679 | DisLoss: 2.1286 | Expert Scores: 0.7707 | Policy Scores: 0.3136
# Prey     | Avg. ES-Reward: 0.3391 | DisLoss: 1.6865 | Expert Scores: 0.6600 | Policy Scores: 0.3454
#
# [Generation 59/200] - Time: 4:36 - Estimated Finish: 26.07.2025 01:59:52
# Predator | Avg. ES-Reward: 0.4191 | DisLoss: 2.0759 | Expert Scores: 0.7708 | Policy Scores: 0.3686
# Prey     | Avg. ES-Reward: 0.2648 | DisLoss: 1.6840 | Expert Scores: 0.6501 | Policy Scores: 0.3162
#
# [Generation 60/200] - Time: 4:42 - Estimated Finish: 26.07.2025 02:15:45
# Predator | Avg. ES-Reward: 0.4193 | DisLoss: 1.9017 | Expert Scores: 0.7826 | Policy Scores: 0.2879
# Prey     | Avg. ES-Reward: 0.2478 | DisLoss: 1.7538 | Expert Scores: 0.6614 | Policy Scores: 0.3272
#
# [Generation 61/200] - Time: 4:37 - Estimated Finish: 26.07.2025 02:02:30
# Predator | Avg. ES-Reward: 0.4211 | DisLoss: 2.0160 | Expert Scores: 0.7810 | Policy Scores: 0.3519
# Prey     | Avg. ES-Reward: 0.2634 | DisLoss: 1.7426 | Expert Scores: 0.6683 | Policy Scores: 0.3111
#
# [Generation 62/200] - Time: 4:50 - Estimated Finish: 26.07.2025 02:32:57
# Predator | Avg. ES-Reward: 0.3978 | DisLoss: 1.9532 | Expert Scores: 0.7739 | Policy Scores: 0.3258
# Prey     | Avg. ES-Reward: 0.3083 | DisLoss: 1.6923 | Expert Scores: 0.6698 | Policy Scores: 0.3236
#
# [Generation 63/200] - Time: 4:42 - Estimated Finish: 26.07.2025 02:15:30
# Predator | Avg. ES-Reward: 0.3715 | DisLoss: 1.9841 | Expert Scores: 0.7841 | Policy Scores: 0.3489
# Prey     | Avg. ES-Reward: 0.2892 | DisLoss: 1.6106 | Expert Scores: 0.6701 | Policy Scores: 0.3744
#
# [Generation 64/200] - Time: 4:24 - Estimated Finish: 26.07.2025 01:34:38
# Predator | Avg. ES-Reward: 0.3792 | DisLoss: 2.0051 | Expert Scores: 0.7765 | Policy Scores: 0.3420
# Prey     | Avg. ES-Reward: 0.2481 | DisLoss: 1.4994 | Expert Scores: 0.6750 | Policy Scores: 0.3547
#
# [Generation 65/200] - Time: 4:25 - Estimated Finish: 26.07.2025 01:36:44
# Predator | Avg. ES-Reward: 0.3914 | DisLoss: 1.9558 | Expert Scores: 0.7939 | Policy Scores: 0.3121
# Prey     | Avg. ES-Reward: 0.2185 | DisLoss: 1.4277 | Expert Scores: 0.6731 | Policy Scores: 0.3218
#
# [Generation 66/200] - Time: 4:33 - Estimated Finish: 26.07.2025 01:53:19
# Predator | Avg. ES-Reward: 0.3864 | DisLoss: 1.9602 | Expert Scores: 0.7741 | Policy Scores: 0.3557
# Prey     | Avg. ES-Reward: 0.3855 | DisLoss: 1.6239 | Expert Scores: 0.6764 | Policy Scores: 0.3491
#
# [Generation 67/200] - Time: 4:33 - Estimated Finish: 26.07.2025 01:53:10
# Predator | Avg. ES-Reward: 0.3740 | DisLoss: 1.9002 | Expert Scores: 0.7884 | Policy Scores: 0.3324
# Prey     | Avg. ES-Reward: 0.3345 | DisLoss: 1.7366 | Expert Scores: 0.6756 | Policy Scores: 0.3765
#
# [Generation 68/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:50:19
# Predator | Avg. ES-Reward: 0.3499 | DisLoss: 1.8424 | Expert Scores: 0.7782 | Policy Scores: 0.3218
# Prey     | Avg. ES-Reward: 0.2639 | DisLoss: 1.7396 | Expert Scores: 0.6711 | Policy Scores: 0.4118
#
# [Generation 69/200] - Time: 4:38 - Estimated Finish: 26.07.2025 02:04:01
# Predator | Avg. ES-Reward: 0.3993 | DisLoss: 1.9377 | Expert Scores: 0.7666 | Policy Scores: 0.3621
# Prey     | Avg. ES-Reward: 0.3389 | DisLoss: 1.6477 | Expert Scores: 0.6705 | Policy Scores: 0.3330
#
# [Generation 70/200] - Time: 4:22 - Estimated Finish: 26.07.2025 01:29:49
# Predator | Avg. ES-Reward: 0.3840 | DisLoss: 1.7716 | Expert Scores: 0.7768 | Policy Scores: 0.3169
# Prey     | Avg. ES-Reward: 0.4490 | DisLoss: 1.5526 | Expert Scores: 0.6699 | Policy Scores: 0.3288
#
# [Generation 71/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:49:53
# Predator | Avg. ES-Reward: 0.4395 | DisLoss: 1.8595 | Expert Scores: 0.7944 | Policy Scores: 0.3530
# Prey     | Avg. ES-Reward: 0.4519 | DisLoss: 1.5269 | Expert Scores: 0.6776 | Policy Scores: 0.3302
#
# [Generation 72/200] - Time: 4:30 - Estimated Finish: 26.07.2025 01:48:22
# Predator | Avg. ES-Reward: 0.3926 | DisLoss: 1.7683 | Expert Scores: 0.7708 | Policy Scores: 0.3014
# Prey     | Avg. ES-Reward: 0.3733 | DisLoss: 1.4924 | Expert Scores: 0.6791 | Policy Scores: 0.3507
#
# [Generation 73/200] - Time: 4:32 - Estimated Finish: 26.07.2025 01:52:28
# Predator | Avg. ES-Reward: 0.4188 | DisLoss: 1.9719 | Expert Scores: 0.7842 | Policy Scores: 0.3949
# Prey     | Avg. ES-Reward: 0.3594 | DisLoss: 1.4491 | Expert Scores: 0.6772 | Policy Scores: 0.3617
#
# [Generation 74/200] - Time: 4:39 - Estimated Finish: 26.07.2025 02:06:34
# Predator | Avg. ES-Reward: 0.3653 | DisLoss: 1.8089 | Expert Scores: 0.7877 | Policy Scores: 0.3288
# Prey     | Avg. ES-Reward: 0.2824 | DisLoss: 1.3776 | Expert Scores: 0.6813 | Policy Scores: 0.3312
#
# [Generation 75/200] - Time: 4:39 - Estimated Finish: 26.07.2025 02:05:52
# Predator | Avg. ES-Reward: 0.3905 | DisLoss: 1.7548 | Expert Scores: 0.7973 | Policy Scores: 0.3091
# Prey     | Avg. ES-Reward: 0.3671 | DisLoss: 1.4514 | Expert Scores: 0.6699 | Policy Scores: 0.3302
#
# [Generation 76/200] - Time: 4:29 - Estimated Finish: 26.07.2025 01:46:15
# Predator | Avg. ES-Reward: 0.3930 | DisLoss: 1.8170 | Expert Scores: 0.7920 | Policy Scores: 0.3350
# Prey     | Avg. ES-Reward: 0.1482 | DisLoss: 1.5428 | Expert Scores: 0.6782 | Policy Scores: 0.3175
#
# [Generation 77/200] - Time: 4:26 - Estimated Finish: 26.07.2025 01:40:22
# Predator | Avg. ES-Reward: 0.4139 | DisLoss: 1.7601 | Expert Scores: 0.7817 | Policy Scores: 0.3558
# Prey     | Avg. ES-Reward: 0.3108 | DisLoss: 1.6125 | Expert Scores: 0.6778 | Policy Scores: 0.3587
#
# [Generation 78/200] - Time: 4:25 - Estimated Finish: 26.07.2025 01:36:42
# Predator | Avg. ES-Reward: 0.3795 | DisLoss: 1.7773 | Expert Scores: 0.7875 | Policy Scores: 0.3396
# Prey     | Avg. ES-Reward: 0.3787 | DisLoss: 1.6937 | Expert Scores: 0.6770 | Policy Scores: 0.3893
#
# [Generation 79/200] - Time: 4:25 - Estimated Finish: 26.07.2025 01:38:00
# Predator | Avg. ES-Reward: 0.3359 | DisLoss: 1.8101 | Expert Scores: 0.7994 | Policy Scores: 0.3518
# Prey     | Avg. ES-Reward: 0.2603 | DisLoss: 1.6700 | Expert Scores: 0.6787 | Policy Scores: 0.3272
#
# [Generation 80/200] - Time: 4:41 - Estimated Finish: 26.07.2025 02:10:01
# Predator | Avg. ES-Reward: 0.3264 | DisLoss: 1.6319 | Expert Scores: 0.7879 | Policy Scores: 0.2743
# Prey     | Avg. ES-Reward: 0.2935 | DisLoss: 1.7391 | Expert Scores: 0.6795 | Policy Scores: 0.3538
#
# [Generation 81/200] - Time: 4:40 - Estimated Finish: 26.07.2025 02:07:18
# Predator | Avg. ES-Reward: 0.4131 | DisLoss: 1.8895 | Expert Scores: 0.7922 | Policy Scores: 0.4017
# Prey     | Avg. ES-Reward: 0.3065 | DisLoss: 1.7238 | Expert Scores: 0.6758 | Policy Scores: 0.3345
#
# [Generation 82/200] - Time: 4:27 - Estimated Finish: 26.07.2025 01:41:03
# Predator | Avg. ES-Reward: 0.4154 | DisLoss: 1.6009 | Expert Scores: 0.7809 | Policy Scores: 0.3151
# Prey     | Avg. ES-Reward: 0.3288 | DisLoss: 1.6413 | Expert Scores: 0.6813 | Policy Scores: 0.3154
#
# [Generation 83/200] - Time: 4:36 - Estimated Finish: 26.07.2025 01:59:03
# Predator | Avg. ES-Reward: 0.3868 | DisLoss: 1.6701 | Expert Scores: 0.7823 | Policy Scores: 0.3380
# Prey     | Avg. ES-Reward: 0.4282 | DisLoss: 1.5711 | Expert Scores: 0.6802 | Policy Scores: 0.3284
#
# [Generation 84/200] - Time: 4:37 - Estimated Finish: 26.07.2025 02:01:59
# Predator | Avg. ES-Reward: 0.3572 | DisLoss: 1.7508 | Expert Scores: 0.7923 | Policy Scores: 0.3503
# Prey     | Avg. ES-Reward: 0.4158 | DisLoss: 1.4697 | Expert Scores: 0.6927 | Policy Scores: 0.3564
#
# [Generation 85/200] - Time: 4:24 - Estimated Finish: 26.07.2025 01:36:12
# Predator | Avg. ES-Reward: 0.3720 | DisLoss: 1.7224 | Expert Scores: 0.7929 | Policy Scores: 0.3548
# Prey     | Avg. ES-Reward: 0.4198 | DisLoss: 1.4329 | Expert Scores: 0.6858 | Policy Scores: 0.3375
#
# [Generation 86/200] - Time: 4:37 - Estimated Finish: 26.07.2025 02:01:12
# Predator | Avg. ES-Reward: 0.3550 | DisLoss: 1.5829 | Expert Scores: 0.7887 | Policy Scores: 0.3088
# Prey     | Avg. ES-Reward: 0.3605 | DisLoss: 1.4359 | Expert Scores: 0.6875 | Policy Scores: 0.3411
#
# [Generation 87/200] - Time: 4:20 - Estimated Finish: 26.07.2025 01:29:55
# Predator | Avg. ES-Reward: 0.3275 | DisLoss: 1.6142 | Expert Scores: 0.8036 | Policy Scores: 0.3301
# Prey     | Avg. ES-Reward: 0.4161 | DisLoss: 1.3626 | Expert Scores: 0.6829 | Policy Scores: 0.3080
#
# [Generation 88/200] - Time: 4:33 - Estimated Finish: 26.07.2025 01:52:53
# Predator | Avg. ES-Reward: 0.3752 | DisLoss: 1.8004 | Expert Scores: 0.8098 | Policy Scores: 0.3748
# Prey     | Avg. ES-Reward: 0.2738 | DisLoss: 1.4961 | Expert Scores: 0.6919 | Policy Scores: 0.4040
#
# [Generation 89/200] - Time: 4:46 - Estimated Finish: 26.07.2025 02:17:08
# Predator | Avg. ES-Reward: 0.4212 | DisLoss: 1.5808 | Expert Scores: 0.7924 | Policy Scores: 0.3154
# Prey     | Avg. ES-Reward: 0.3112 | DisLoss: 1.3942 | Expert Scores: 0.6876 | Policy Scores: 0.3191
#
# [Generation 90/200] - Time: 4:37 - Estimated Finish: 26.07.2025 02:01:04
# Predator | Avg. ES-Reward: 0.4126 | DisLoss: 1.6360 | Expert Scores: 0.7926 | Policy Scores: 0.3278
# Prey     | Avg. ES-Reward: 0.2473 | DisLoss: 1.5017 | Expert Scores: 0.6833 | Policy Scores: 0.3610
#
# [Generation 91/200] - Time: 4:19 - Estimated Finish: 26.07.2025 01:28:20
# Predator | Avg. ES-Reward: 0.3589 | DisLoss: 1.5436 | Expert Scores: 0.8080 | Policy Scores: 0.3282
# Prey     | Avg. ES-Reward: 0.2719 | DisLoss: 1.5609 | Expert Scores: 0.6898 | Policy Scores: 0.3567
#
# [Generation 92/200] - Time: 4:20 - Estimated Finish: 26.07.2025 01:29:38
# Predator | Avg. ES-Reward: 0.3585 | DisLoss: 1.6166 | Expert Scores: 0.7949 | Policy Scores: 0.3207
# Prey     | Avg. ES-Reward: 0.3373 | DisLoss: 1.6417 | Expert Scores: 0.6946 | Policy Scores: 0.3853
#
# [Generation 93/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:48:58
# Predator | Avg. ES-Reward: 0.3562 | DisLoss: 1.4845 | Expert Scores: 0.7997 | Policy Scores: 0.2950
# Prey     | Avg. ES-Reward: 0.3650 | DisLoss: 1.6578 | Expert Scores: 0.6947 | Policy Scores: 0.3469
#
# [Generation 94/200] - Time: 4:35 - Estimated Finish: 26.07.2025 01:56:02
# Predator | Avg. ES-Reward: 0.3338 | DisLoss: 1.6238 | Expert Scores: 0.8154 | Policy Scores: 0.3694
# Prey     | Avg. ES-Reward: 0.3298 | DisLoss: 1.7011 | Expert Scores: 0.6829 | Policy Scores: 0.3580
#
# [Generation 95/200] - Time: 4:21 - Estimated Finish: 26.07.2025 01:32:15
# Predator | Avg. ES-Reward: 0.3257 | DisLoss: 1.5722 | Expert Scores: 0.8071 | Policy Scores: 0.3221
# Prey     | Avg. ES-Reward: 0.3611 | DisLoss: 1.6599 | Expert Scores: 0.6814 | Policy Scores: 0.3337
#
# [Generation 96/200] - Time: 4:29 - Estimated Finish: 26.07.2025 01:45:50
# Predator | Avg. ES-Reward: 0.3295 | DisLoss: 1.6255 | Expert Scores: 0.8019 | Policy Scores: 0.3530
# Prey     | Avg. ES-Reward: 0.2652 | DisLoss: 1.5525 | Expert Scores: 0.6821 | Policy Scores: 0.2966
#
# [Generation 97/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:49:48
# Predator | Avg. ES-Reward: 0.3455 | DisLoss: 1.5754 | Expert Scores: 0.8148 | Policy Scores: 0.3177
# Prey     | Avg. ES-Reward: 0.2883 | DisLoss: 1.5745 | Expert Scores: 0.6814 | Policy Scores: 0.3331
#
# [Generation 98/200] - Time: 4:35 - Estimated Finish: 26.07.2025 01:55:48
# Predator | Avg. ES-Reward: 0.4278 | DisLoss: 1.5634 | Expert Scores: 0.7895 | Policy Scores: 0.3155
# Prey     | Avg. ES-Reward: 0.4427 | DisLoss: 1.4700 | Expert Scores: 0.6936 | Policy Scores: 0.3529
#
# [Generation 99/200] - Time: 4:49 - Estimated Finish: 26.07.2025 02:19:48
# Predator | Avg. ES-Reward: 0.3431 | DisLoss: 1.7155 | Expert Scores: 0.7994 | Policy Scores: 0.3583
# Prey     | Avg. ES-Reward: 0.3791 | DisLoss: 1.4724 | Expert Scores: 0.6947 | Policy Scores: 0.3511
#
# [Generation 100/200] - Time: 4:32 - Estimated Finish: 26.07.2025 01:51:41
# Predator | Avg. ES-Reward: 0.3563 | DisLoss: 1.5122 | Expert Scores: 0.7853 | Policy Scores: 0.2845
# Prey     | Avg. ES-Reward: 0.4474 | DisLoss: 1.4332 | Expert Scores: 0.6978 | Policy Scores: 0.3309
#
# [Generation 101/200] - Time: 4:32 - Estimated Finish: 26.07.2025 01:51:23
# Predator | Avg. ES-Reward: 0.3048 | DisLoss: 1.5735 | Expert Scores: 0.7982 | Policy Scores: 0.3126
# Prey     | Avg. ES-Reward: 0.3916 | DisLoss: 1.5111 | Expert Scores: 0.6898 | Policy Scores: 0.3700
#
# Checkpoint successfully saved!
#
# [Generation 102/200] - Time: 4:38 - Estimated Finish: 26.07.2025 02:01:19
# Predator | Avg. ES-Reward: 0.3328 | DisLoss: 1.7452 | Expert Scores: 0.8160 | Policy Scores: 0.3906
# Prey     | Avg. ES-Reward: 0.3118 | DisLoss: 1.4265 | Expert Scores: 0.6925 | Policy Scores: 0.3415
#
# [Generation 103/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:49:24
# Predator | Avg. ES-Reward: 0.3797 | DisLoss: 1.4890 | Expert Scores: 0.8095 | Policy Scores: 0.3050
# Prey     | Avg. ES-Reward: 0.3491 | DisLoss: 1.4422 | Expert Scores: 0.6971 | Policy Scores: 0.3282
#
# [Generation 104/200] - Time: 4:36 - Estimated Finish: 26.07.2025 01:57:35
# Predator | Avg. ES-Reward: 0.3317 | DisLoss: 1.5634 | Expert Scores: 0.8169 | Policy Scores: 0.3798
# Prey     | Avg. ES-Reward: 0.3923 | DisLoss: 1.4668 | Expert Scores: 0.6927 | Policy Scores: 0.3653
#
# [Generation 105/200] - Time: 4:35 - Estimated Finish: 26.07.2025 01:56:44
# Predator | Avg. ES-Reward: 0.3572 | DisLoss: 1.4722 | Expert Scores: 0.8158 | Policy Scores: 0.2766
# Prey     | Avg. ES-Reward: 0.3736 | DisLoss: 1.4190 | Expert Scores: 0.7054 | Policy Scores: 0.3352
#
# [Generation 106/200] - Time: 4:27 - Estimated Finish: 26.07.2025 01:43:37
# Predator | Avg. ES-Reward: 0.4032 | DisLoss: 1.5753 | Expert Scores: 0.8174 | Policy Scores: 0.3483
# Prey     | Avg. ES-Reward: 0.2295 | DisLoss: 1.3730 | Expert Scores: 0.6992 | Policy Scores: 0.3193
#
# [Generation 107/200] - Time: 4:29 - Estimated Finish: 26.07.2025 01:46:17
# Predator | Avg. ES-Reward: 0.4360 | DisLoss: 1.6126 | Expert Scores: 0.8062 | Policy Scores: 0.3604
# Prey     | Avg. ES-Reward: 0.2747 | DisLoss: 1.4294 | Expert Scores: 0.7078 | Policy Scores: 0.3425
#
# [Generation 108/200] - Time: 4:30 - Estimated Finish: 26.07.2025 01:48:04
# Predator | Avg. ES-Reward: 0.4276 | DisLoss: 1.6138 | Expert Scores: 0.8231 | Policy Scores: 0.3598
# Prey     | Avg. ES-Reward: 0.2775 | DisLoss: 1.4764 | Expert Scores: 0.7060 | Policy Scores: 0.3559
#
# [Generation 109/200] - Time: 4:28 - Estimated Finish: 26.07.2025 01:45:33
# Predator | Avg. ES-Reward: 0.2923 | DisLoss: 1.4918 | Expert Scores: 0.8196 | Policy Scores: 0.3265
# Prey     | Avg. ES-Reward: 0.3817 | DisLoss: 1.4701 | Expert Scores: 0.7081 | Policy Scores: 0.3551
#
# [Generation 110/200] - Time: 4:33 - Estimated Finish: 26.07.2025 01:52:20
# Predator | Avg. ES-Reward: 0.3569 | DisLoss: 1.5951 | Expert Scores: 0.8028 | Policy Scores: 0.3517
# Prey     | Avg. ES-Reward: 0.3907 | DisLoss: 1.5053 | Expert Scores: 0.7123 | Policy Scores: 0.3622
#
# [Generation 111/200] - Time: 4:36 - Estimated Finish: 26.07.2025 01:57:41
# Predator | Avg. ES-Reward: 0.3365 | DisLoss: 1.4919 | Expert Scores: 0.8204 | Policy Scores: 0.3386
# Prey     | Avg. ES-Reward: 0.3744 | DisLoss: 1.5206 | Expert Scores: 0.7075 | Policy Scores: 0.3446
#
# [Generation 112/200] - Time: 4:35 - Estimated Finish: 26.07.2025 01:56:48
# Predator | Avg. ES-Reward: 0.4091 | DisLoss: 1.6560 | Expert Scores: 0.8220 | Policy Scores: 0.4030
# Prey     | Avg. ES-Reward: 0.3050 | DisLoss: 1.6329 | Expert Scores: 0.7018 | Policy Scores: 0.3616
#
# [Generation 113/200] - Time: 4:23 - Estimated Finish: 26.07.2025 01:38:10
# Predator | Avg. ES-Reward: 0.3620 | DisLoss: 1.5006 | Expert Scores: 0.8199 | Policy Scores: 0.2894
# Prey     | Avg. ES-Reward: 0.2541 | DisLoss: 1.6889 | Expert Scores: 0.6948 | Policy Scores: 0.3279
#
# [Generation 114/200] - Time: 4:22 - Estimated Finish: 26.07.2025 01:37:02
# Predator | Avg. ES-Reward: 0.3799 | DisLoss: 1.6052 | Expert Scores: 0.8145 | Policy Scores: 0.3643
# Prey     | Avg. ES-Reward: 0.2667 | DisLoss: 1.7201 | Expert Scores: 0.7051 | Policy Scores: 0.3598
#
# [Generation 115/200] - Time: 4:28 - Estimated Finish: 26.07.2025 01:46:09
# Predator | Avg. ES-Reward: 0.4296 | DisLoss: 1.5754 | Expert Scores: 0.8080 | Policy Scores: 0.3399
# Prey     | Avg. ES-Reward: 0.3346 | DisLoss: 1.5869 | Expert Scores: 0.7047 | Policy Scores: 0.3409
#
# [Generation 116/200] - Time: 4:40 - Estimated Finish: 26.07.2025 02:03:00
# Predator | Avg. ES-Reward: 0.3823 | DisLoss: 1.5120 | Expert Scores: 0.8108 | Policy Scores: 0.3530
# Prey     | Avg. ES-Reward: 0.3787 | DisLoss: 1.4360 | Expert Scores: 0.7054 | Policy Scores: 0.3361
#
# [Generation 117/200] - Time: 4:36 - Estimated Finish: 26.07.2025 01:56:44
# Predator | Avg. ES-Reward: 0.3797 | DisLoss: 1.5237 | Expert Scores: 0.8287 | Policy Scores: 0.3394
# Prey     | Avg. ES-Reward: 0.3628 | DisLoss: 1.3399 | Expert Scores: 0.7114 | Policy Scores: 0.3289
#
# [Generation 118/200] - Time: 4:38 - Estimated Finish: 26.07.2025 02:00:23
# Predator | Avg. ES-Reward: 0.3532 | DisLoss: 1.5194 | Expert Scores: 0.8149 | Policy Scores: 0.3221
# Prey     | Avg. ES-Reward: 0.3828 | DisLoss: 1.4716 | Expert Scores: 0.7053 | Policy Scores: 0.3662
#
# [Generation 119/200] - Time: 4:34 - Estimated Finish: 26.07.2025 01:53:44
# Predator | Avg. ES-Reward: 0.3140 | DisLoss: 1.4194 | Expert Scores: 0.8255 | Policy Scores: 0.3135
# Prey     | Avg. ES-Reward: 0.4102 | DisLoss: 1.4274 | Expert Scores: 0.7077 | Policy Scores: 0.3392
#
# [Generation 120/200] - Time: 4:30 - Estimated Finish: 26.07.2025 01:48:52
# Predator | Avg. ES-Reward: 0.3544 | DisLoss: 1.4918 | Expert Scores: 0.8283 | Policy Scores: 0.3426
# Prey     | Avg. ES-Reward: 0.3285 | DisLoss: 1.5654 | Expert Scores: 0.7121 | Policy Scores: 0.3962
#
# [Generation 121/200] - Time: 4:36 - Estimated Finish: 26.07.2025 01:57:01
# Predator | Avg. ES-Reward: 0.3120 | DisLoss: 1.3806 | Expert Scores: 0.8156 | Policy Scores: 0.2807
# Prey     | Avg. ES-Reward: 0.3356 | DisLoss: 1.4812 | Expert Scores: 0.7110 | Policy Scores: 0.3157
#
# [Generation 122/200] - Time: 4:38 - Estimated Finish: 26.07.2025 02:00:02
# Predator | Avg. ES-Reward: 0.3236 | DisLoss: 1.6583 | Expert Scores: 0.8224 | Policy Scores: 0.3495
# Prey     | Avg. ES-Reward: 0.2295 | DisLoss: 1.4771 | Expert Scores: 0.7183 | Policy Scores: 0.3890
#
# [Generation 123/200] - Time: 4:27 - Estimated Finish: 26.07.2025 01:45:30
# Predator | Avg. ES-Reward: 0.3588 | DisLoss: 1.3975 | Expert Scores: 0.8105 | Policy Scores: 0.3406
# Prey     | Avg. ES-Reward: 0.2949 | DisLoss: 1.4968 | Expert Scores: 0.7107 | Policy Scores: 0.2838
#
# [Generation 124/200] - Time: 4:47 - Estimated Finish: 26.07.2025 02:10:35
# Predator | Avg. ES-Reward: 0.3104 | DisLoss: 1.4542 | Expert Scores: 0.8086 | Policy Scores: 0.2805
# Prey     | Avg. ES-Reward: 0.2481 | DisLoss: 1.4689 | Expert Scores: 0.7223 | Policy Scores: 0.4015
#
# [Generation 125/200] - Time: 4:22 - Estimated Finish: 26.07.2025 01:39:23
# Predator | Avg. ES-Reward: 0.3661 | DisLoss: 1.6034 | Expert Scores: 0.8068 | Policy Scores: 0.3707
# Prey     | Avg. ES-Reward: 0.2422 | DisLoss: 1.4607 | Expert Scores: 0.7058 | Policy Scores: 0.2996
#
# [Generation 126/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:50:12
# Predator | Avg. ES-Reward: 0.4052 | DisLoss: 1.5172 | Expert Scores: 0.8208 | Policy Scores: 0.3163
# Prey     | Avg. ES-Reward: 0.3341 | DisLoss: 1.4169 | Expert Scores: 0.7116 | Policy Scores: 0.3481
#
# [Generation 127/200] - Time: 4:40 - Estimated Finish: 26.07.2025 02:01:26
# Predator | Avg. ES-Reward: 0.3391 | DisLoss: 1.4924 | Expert Scores: 0.8098 | Policy Scores: 0.3373
# Prey     | Avg. ES-Reward: 0.3580 | DisLoss: 1.4291 | Expert Scores: 0.7126 | Policy Scores: 0.3316
#
# [Generation 128/200] - Time: 4:25 - Estimated Finish: 26.07.2025 01:43:33
# Predator | Avg. ES-Reward: 0.3267 | DisLoss: 1.5326 | Expert Scores: 0.8201 | Policy Scores: 0.3508
# Prey     | Avg. ES-Reward: 0.4240 | DisLoss: 1.5185 | Expert Scores: 0.7132 | Policy Scores: 0.3583
#
# [Generation 129/200] - Time: 4:19 - Estimated Finish: 26.07.2025 01:35:48
# Predator | Avg. ES-Reward: 0.2940 | DisLoss: 1.4259 | Expert Scores: 0.8198 | Policy Scores: 0.3274
# Prey     | Avg. ES-Reward: 0.3688 | DisLoss: 1.6169 | Expert Scores: 0.7102 | Policy Scores: 0.3608
#
# [Generation 130/200] - Time: 4:34 - Estimated Finish: 26.07.2025 01:53:48
# Predator | Avg. ES-Reward: 0.3172 | DisLoss: 1.4369 | Expert Scores: 0.8188 | Policy Scores: 0.3190
# Prey     | Avg. ES-Reward: 0.3229 | DisLoss: 1.6495 | Expert Scores: 0.7030 | Policy Scores: 0.3271
#
# [Generation 131/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:49:53
# Predator | Avg. ES-Reward: 0.3231 | DisLoss: 1.4322 | Expert Scores: 0.8255 | Policy Scores: 0.2906
# Prey     | Avg. ES-Reward: 0.3436 | DisLoss: 1.6372 | Expert Scores: 0.7104 | Policy Scores: 0.3447
#
# [Generation 132/200] - Time: 4:35 - Estimated Finish: 26.07.2025 01:54:43
# Predator | Avg. ES-Reward: 0.3050 | DisLoss: 1.3514 | Expert Scores: 0.8346 | Policy Scores: 0.3047
# Prey     | Avg. ES-Reward: 0.2770 | DisLoss: 1.6311 | Expert Scores: 0.7002 | Policy Scores: 0.3479
#
# [Generation 133/200] - Time: 4:28 - Estimated Finish: 26.07.2025 01:46:51
# Predator | Avg. ES-Reward: 0.3342 | DisLoss: 1.5941 | Expert Scores: 0.8325 | Policy Scores: 0.3865
# Prey     | Avg. ES-Reward: 0.2991 | DisLoss: 1.6140 | Expert Scores: 0.7040 | Policy Scores: 0.3264
#
# [Generation 134/200] - Time: 4:30 - Estimated Finish: 26.07.2025 01:49:32
# Predator | Avg. ES-Reward: 0.3701 | DisLoss: 1.3429 | Expert Scores: 0.8215 | Policy Scores: 0.2958
# Prey     | Avg. ES-Reward: 0.2935 | DisLoss: 1.5999 | Expert Scores: 0.7013 | Policy Scores: 0.3512
#
# [Generation 135/200] - Time: 4:27 - Estimated Finish: 26.07.2025 01:46:28
# Predator | Avg. ES-Reward: 0.3398 | DisLoss: 1.4271 | Expert Scores: 0.8234 | Policy Scores: 0.3471
# Prey     | Avg. ES-Reward: 0.2862 | DisLoss: 1.5569 | Expert Scores: 0.7064 | Policy Scores: 0.3198
#
# [Generation 136/200] - Time: 4:32 - Estimated Finish: 26.07.2025 01:51:06
# Predator | Avg. ES-Reward: 0.3008 | DisLoss: 1.2979 | Expert Scores: 0.8146 | Policy Scores: 0.2796
# Prey     | Avg. ES-Reward: 0.3538 | DisLoss: 1.5521 | Expert Scores: 0.7138 | Policy Scores: 0.3511
#
# [Generation 137/200] - Time: 4:24 - Estimated Finish: 26.07.2025 01:43:15
# Predator | Avg. ES-Reward: 0.3709 | DisLoss: 1.4881 | Expert Scores: 0.8486 | Policy Scores: 0.3643
# Prey     | Avg. ES-Reward: 0.2821 | DisLoss: 1.3819 | Expert Scores: 0.7183 | Policy Scores: 0.2827
#
# [Generation 138/200] - Time: 5:36 - Estimated Finish: 26.07.2025 02:58:16
# Predator | Avg. ES-Reward: 0.4704 | DisLoss: 1.2995 | Expert Scores: 0.8269 | Policy Scores: 0.2964
# Prey     | Avg. ES-Reward: 0.2675 | DisLoss: 1.3102 | Expert Scores: 0.7150 | Policy Scores: 0.3031
#
# [Generation 139/200] - Time: 5:16 - Estimated Finish: 26.07.2025 02:37:19
# Predator | Avg. ES-Reward: 0.4547 | DisLoss: 1.4349 | Expert Scores: 0.8271 | Policy Scores: 0.3284
# Prey     | Avg. ES-Reward: 0.3450 | DisLoss: 1.2469 | Expert Scores: 0.7288 | Policy Scores: 0.3147
#
# [Generation 140/200] - Time: 4:18 - Estimated Finish: 26.07.2025 01:39:16
# Predator | Avg. ES-Reward: 0.3965 | DisLoss: 1.3066 | Expert Scores: 0.8179 | Policy Scores: 0.2928
# Prey     | Avg. ES-Reward: 0.3675 | DisLoss: 1.3122 | Expert Scores: 0.7182 | Policy Scores: 0.3164
#
# [Generation 141/200] - Time: 4:22 - Estimated Finish: 26.07.2025 01:42:44
# Predator | Avg. ES-Reward: 0.3823 | DisLoss: 1.3177 | Expert Scores: 0.8199 | Policy Scores: 0.2879
# Prey     | Avg. ES-Reward: 0.3887 | DisLoss: 1.2939 | Expert Scores: 0.7273 | Policy Scores: 0.2921
#
# [Generation 142/200] - Time: 4:34 - Estimated Finish: 26.07.2025 01:54:30
# Predator | Avg. ES-Reward: 0.4088 | DisLoss: 1.4653 | Expert Scores: 0.8383 | Policy Scores: 0.3378
# Prey     | Avg. ES-Reward: 0.3533 | DisLoss: 1.2734 | Expert Scores: 0.7232 | Policy Scores: 0.2897
#
# [Generation 143/200] - Time: 4:33 - Estimated Finish: 26.07.2025 01:53:51
# Predator | Avg. ES-Reward: 0.4119 | DisLoss: 1.3862 | Expert Scores: 0.8208 | Policy Scores: 0.3431
# Prey     | Avg. ES-Reward: 0.3217 | DisLoss: 1.2206 | Expert Scores: 0.7312 | Policy Scores: 0.2825
#
# [Generation 144/200] - Time: 4:27 - Estimated Finish: 26.07.2025 01:48:13
# Predator | Avg. ES-Reward: 0.4093 | DisLoss: 1.4053 | Expert Scores: 0.8172 | Policy Scores: 0.3205
# Prey     | Avg. ES-Reward: 0.3538 | DisLoss: 1.2144 | Expert Scores: 0.7292 | Policy Scores: 0.2937
#
# [Generation 145/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:52:01
# Predator | Avg. ES-Reward: 0.4269 | DisLoss: 1.3141 | Expert Scores: 0.8355 | Policy Scores: 0.3066
# Prey     | Avg. ES-Reward: 0.3143 | DisLoss: 1.2181 | Expert Scores: 0.7408 | Policy Scores: 0.2890
#
# [Generation 146/200] - Time: 4:22 - Estimated Finish: 26.07.2025 01:43:02
# Predator | Avg. ES-Reward: 0.4287 | DisLoss: 1.4199 | Expert Scores: 0.8269 | Policy Scores: 0.3463
# Prey     | Avg. ES-Reward: 0.3145 | DisLoss: 1.2788 | Expert Scores: 0.7401 | Policy Scores: 0.2966
#
# [Generation 147/200] - Time: 4:26 - Estimated Finish: 26.07.2025 01:47:00
# Predator | Avg. ES-Reward: 0.4046 | DisLoss: 1.3539 | Expert Scores: 0.8127 | Policy Scores: 0.2916
# Prey     | Avg. ES-Reward: 0.3400 | DisLoss: 1.4168 | Expert Scores: 0.7382 | Policy Scores: 0.3286
#
# [Generation 148/200] - Time: 4:24 - Estimated Finish: 26.07.2025 01:45:23
# Predator | Avg. ES-Reward: 0.3208 | DisLoss: 1.3482 | Expert Scores: 0.8326 | Policy Scores: 0.3053
# Prey     | Avg. ES-Reward: 0.2828 | DisLoss: 1.5553 | Expert Scores: 0.7395 | Policy Scores: 0.3483
#
# [Generation 149/200] - Time: 4:32 - Estimated Finish: 26.07.2025 01:51:54
# Predator | Avg. ES-Reward: 0.3376 | DisLoss: 1.3114 | Expert Scores: 0.8136 | Policy Scores: 0.3139
# Prey     | Avg. ES-Reward: 0.2927 | DisLoss: 1.5698 | Expert Scores: 0.7416 | Policy Scores: 0.3565
#
# [Generation 150/200] - Time: 4:20 - Estimated Finish: 26.07.2025 01:41:46
# Predator | Avg. ES-Reward: 0.3655 | DisLoss: 1.3961 | Expert Scores: 0.8203 | Policy Scores: 0.3338
# Prey     | Avg. ES-Reward: 0.3346 | DisLoss: 1.5322 | Expert Scores: 0.7372 | Policy Scores: 0.3324
#
# [Generation 151/200] - Time: 4:32 - Estimated Finish: 26.07.2025 01:52:11
# Predator | Avg. ES-Reward: 0.3952 | DisLoss: 1.3325 | Expert Scores: 0.8318 | Policy Scores: 0.2975
# Prey     | Avg. ES-Reward: 0.4009 | DisLoss: 1.3412 | Expert Scores: 0.7414 | Policy Scores: 0.3104
#
# Checkpoint successfully saved!
#
# [Generation 152/200] - Time: 4:38 - Estimated Finish: 26.07.2025 01:57:02
# Predator | Avg. ES-Reward: 0.4083 | DisLoss: 1.3376 | Expert Scores: 0.8164 | Policy Scores: 0.3104
# Prey     | Avg. ES-Reward: 0.3150 | DisLoss: 1.3023 | Expert Scores: 0.7474 | Policy Scores: 0.3015
#
# [Generation 153/200] - Time: 4:36 - Estimated Finish: 26.07.2025 01:55:12
# Predator | Avg. ES-Reward: 0.3436 | DisLoss: 1.3541 | Expert Scores: 0.7983 | Policy Scores: 0.3036
# Prey     | Avg. ES-Reward: 0.3883 | DisLoss: 1.3988 | Expert Scores: 0.7355 | Policy Scores: 0.3413
#
# [Generation 154/200] - Time: 4:32 - Estimated Finish: 26.07.2025 01:51:55
# Predator | Avg. ES-Reward: 0.3280 | DisLoss: 1.3301 | Expert Scores: 0.8149 | Policy Scores: 0.3226
# Prey     | Avg. ES-Reward: 0.3784 | DisLoss: 1.3608 | Expert Scores: 0.7395 | Policy Scores: 0.3214
#
# [Generation 155/200] - Time: 4:29 - Estimated Finish: 26.07.2025 01:49:55
# Predator | Avg. ES-Reward: 0.3200 | DisLoss: 1.3202 | Expert Scores: 0.8118 | Policy Scores: 0.3281
# Prey     | Avg. ES-Reward: 0.3658 | DisLoss: 1.4038 | Expert Scores: 0.7442 | Policy Scores: 0.3345
#
# [Generation 156/200] - Time: 4:37 - Estimated Finish: 26.07.2025 01:56:06
# Predator | Avg. ES-Reward: 0.3510 | DisLoss: 1.3181 | Expert Scores: 0.8090 | Policy Scores: 0.2735
# Prey     | Avg. ES-Reward: 0.3316 | DisLoss: 1.3275 | Expert Scores: 0.7511 | Policy Scores: 0.2959
#
# [Generation 157/200] - Time: 4:38 - Estimated Finish: 26.07.2025 01:56:35
# Predator | Avg. ES-Reward: 0.4123 | DisLoss: 1.4418 | Expert Scores: 0.8083 | Policy Scores: 0.3616
# Prey     | Avg. ES-Reward: 0.3580 | DisLoss: 1.3032 | Expert Scores: 0.7504 | Policy Scores: 0.3108
#
# [Generation 158/200] - Time: 4:34 - Estimated Finish: 26.07.2025 01:53:29
# Predator | Avg. ES-Reward: 0.3777 | DisLoss: 1.4224 | Expert Scores: 0.8179 | Policy Scores: 0.3105
# Prey     | Avg. ES-Reward: 0.3350 | DisLoss: 1.2889 | Expert Scores: 0.7493 | Policy Scores: 0.2715
#
# [Generation 159/200] - Time: 4:24 - Estimated Finish: 26.07.2025 01:46:35
# Predator | Avg. ES-Reward: 0.3596 | DisLoss: 1.3962 | Expert Scores: 0.8221 | Policy Scores: 0.3239
# Prey     | Avg. ES-Reward: 0.3176 | DisLoss: 1.2472 | Expert Scores: 0.7480 | Policy Scores: 0.2580
#
# [Generation 160/200] - Time: 4:20 - Estimated Finish: 26.07.2025 01:43:55
# Predator | Avg. ES-Reward: 0.3246 | DisLoss: 1.4359 | Expert Scores: 0.8157 | Policy Scores: 0.3294
# Prey     | Avg. ES-Reward: 0.3321 | DisLoss: 1.3386 | Expert Scores: 0.7568 | Policy Scores: 0.2872
#
# [Generation 161/200] - Time: 4:35 - Estimated Finish: 26.07.2025 01:54:19
# Predator | Avg. ES-Reward: 0.3145 | DisLoss: 1.3627 | Expert Scores: 0.8040 | Policy Scores: 0.3296
# Prey     | Avg. ES-Reward: 0.3489 | DisLoss: 1.5574 | Expert Scores: 0.7543 | Policy Scores: 0.3813
#
# [Generation 162/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:51:20
# Predator | Avg. ES-Reward: 0.2828 | DisLoss: 1.3419 | Expert Scores: 0.8184 | Policy Scores: 0.3234
# Prey     | Avg. ES-Reward: 0.3595 | DisLoss: 1.5648 | Expert Scores: 0.7410 | Policy Scores: 0.3665
#
# [Generation 163/200] - Time: 4:28 - Estimated Finish: 26.07.2025 01:49:28
# Predator | Avg. ES-Reward: 0.3226 | DisLoss: 1.3741 | Expert Scores: 0.8106 | Policy Scores: 0.2967
# Prey     | Avg. ES-Reward: 0.3199 | DisLoss: 1.5343 | Expert Scores: 0.7370 | Policy Scores: 0.3194
#
# [Generation 164/200] - Time: 4:39 - Estimated Finish: 26.07.2025 01:56:32
# Predator | Avg. ES-Reward: 0.3574 | DisLoss: 1.4530 | Expert Scores: 0.8093 | Policy Scores: 0.3175
# Prey     | Avg. ES-Reward: 0.3562 | DisLoss: 1.4535 | Expert Scores: 0.7381 | Policy Scores: 0.3369
#
# [Generation 165/200] - Time: 4:41 - Estimated Finish: 26.07.2025 01:57:24
# Predator | Avg. ES-Reward: 0.3536 | DisLoss: 1.3931 | Expert Scores: 0.8148 | Policy Scores: 0.3260
# Prey     | Avg. ES-Reward: 0.3183 | DisLoss: 1.3495 | Expert Scores: 0.7410 | Policy Scores: 0.3070
#
# [Generation 166/200] - Time: 4:23 - Estimated Finish: 26.07.2025 01:46:46
# Predator | Avg. ES-Reward: 0.3789 | DisLoss: 1.3979 | Expert Scores: 0.8314 | Policy Scores: 0.3532
# Prey     | Avg. ES-Reward: 0.3061 | DisLoss: 1.2692 | Expert Scores: 0.7450 | Policy Scores: 0.3111
#
# [Generation 167/200] - Time: 4:35 - Estimated Finish: 26.07.2025 01:53:55
# Predator | Avg. ES-Reward: 0.3610 | DisLoss: 1.4427 | Expert Scores: 0.8269 | Policy Scores: 0.3401
# Prey     | Avg. ES-Reward: 0.3590 | DisLoss: 1.2401 | Expert Scores: 0.7536 | Policy Scores: 0.3245
#
# [Generation 168/200] - Time: 4:30 - Estimated Finish: 26.07.2025 01:51:12
# Predator | Avg. ES-Reward: 0.3027 | DisLoss: 1.3896 | Expert Scores: 0.8188 | Policy Scores: 0.2915
# Prey     | Avg. ES-Reward: 0.3580 | DisLoss: 1.3257 | Expert Scores: 0.7494 | Policy Scores: 0.3174
#
# [Generation 169/200] - Time: 4:27 - Estimated Finish: 26.07.2025 01:49:39
# Predator | Avg. ES-Reward: 0.3252 | DisLoss: 1.3886 | Expert Scores: 0.8294 | Policy Scores: 0.3084
# Prey     | Avg. ES-Reward: 0.3689 | DisLoss: 1.2534 | Expert Scores: 0.7515 | Policy Scores: 0.2888
#
# [Generation 170/200] - Time: 4:26 - Estimated Finish: 26.07.2025 01:48:44
# Predator | Avg. ES-Reward: 0.3991 | DisLoss: 1.4295 | Expert Scores: 0.8383 | Policy Scores: 0.3444
# Prey     | Avg. ES-Reward: 0.3227 | DisLoss: 1.2458 | Expert Scores: 0.7446 | Policy Scores: 0.2899
#
# [Generation 171/200] - Time: 4:38 - Estimated Finish: 26.07.2025 01:54:50
# Predator | Avg. ES-Reward: 0.3497 | DisLoss: 1.4994 | Expert Scores: 0.8215 | Policy Scores: 0.3469
# Prey     | Avg. ES-Reward: 0.2640 | DisLoss: 1.2773 | Expert Scores: 0.7570 | Policy Scores: 0.3020
#
# [Generation 172/200] - Time: 4:22 - Estimated Finish: 26.07.2025 01:47:20
# Predator | Avg. ES-Reward: 0.3187 | DisLoss: 1.4947 | Expert Scores: 0.8292 | Policy Scores: 0.3083
# Prey     | Avg. ES-Reward: 0.3629 | DisLoss: 1.3440 | Expert Scores: 0.7564 | Policy Scores: 0.3293
#
# [Generation 173/200] - Time: 4:22 - Estimated Finish: 26.07.2025 01:47:06
# Predator | Avg. ES-Reward: 0.2365 | DisLoss: 1.5692 | Expert Scores: 0.8163 | Policy Scores: 0.3407
# Prey     | Avg. ES-Reward: 0.3977 | DisLoss: 1.3792 | Expert Scores: 0.7478 | Policy Scores: 0.3502
#
# [Generation 174/200] - Time: 4:24 - Estimated Finish: 26.07.2025 01:48:14
# Predator | Avg. ES-Reward: 0.2768 | DisLoss: 1.4831 | Expert Scores: 0.8365 | Policy Scores: 0.3496
# Prey     | Avg. ES-Reward: 0.3437 | DisLoss: 1.3858 | Expert Scores: 0.7559 | Policy Scores: 0.3428
#
# [Generation 175/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:51:11
# Predator | Avg. ES-Reward: 0.3120 | DisLoss: 1.4478 | Expert Scores: 0.8222 | Policy Scores: 0.3298
# Prey     | Avg. ES-Reward: 0.3001 | DisLoss: 1.3651 | Expert Scores: 0.7504 | Policy Scores: 0.3062
#
# [Generation 176/200] - Time: 4:29 - Estimated Finish: 26.07.2025 01:50:14
# Predator | Avg. ES-Reward: 0.3080 | DisLoss: 1.4477 | Expert Scores: 0.8056 | Policy Scores: 0.3011
# Prey     | Avg. ES-Reward: 0.3415 | DisLoss: 1.3271 | Expert Scores: 0.7608 | Policy Scores: 0.2985
#
# [Generation 177/200] - Time: 4:27 - Estimated Finish: 26.07.2025 01:49:42
# Predator | Avg. ES-Reward: 0.2801 | DisLoss: 1.4644 | Expert Scores: 0.8273 | Policy Scores: 0.3350
# Prey     | Avg. ES-Reward: 0.3481 | DisLoss: 1.3530 | Expert Scores: 0.7620 | Policy Scores: 0.3369
#
# [Generation 178/200] - Time: 4:21 - Estimated Finish: 26.07.2025 01:47:24
# Predator | Avg. ES-Reward: 0.3090 | DisLoss: 1.4736 | Expert Scores: 0.8187 | Policy Scores: 0.3503
# Prey     | Avg. ES-Reward: 0.3771 | DisLoss: 1.3927 | Expert Scores: 0.7619 | Policy Scores: 0.2940
#
# [Generation 179/200] - Time: 4:17 - Estimated Finish: 26.07.2025 01:45:45
# Predator | Avg. ES-Reward: 0.3103 | DisLoss: 1.4161 | Expert Scores: 0.8166 | Policy Scores: 0.3297
# Prey     | Avg. ES-Reward: 0.2680 | DisLoss: 1.3986 | Expert Scores: 0.7584 | Policy Scores: 0.3363
#
# [Generation 180/200] - Time: 4:37 - Estimated Finish: 26.07.2025 01:52:47
# Predator | Avg. ES-Reward: 0.2990 | DisLoss: 1.4534 | Expert Scores: 0.8087 | Policy Scores: 0.3320
# Prey     | Avg. ES-Reward: 0.3637 | DisLoss: 1.4989 | Expert Scores: 0.7642 | Policy Scores: 0.3527
#
# [Generation 181/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:50:46
# Predator | Avg. ES-Reward: 0.3416 | DisLoss: 1.3698 | Expert Scores: 0.8049 | Policy Scores: 0.3733
# Prey     | Avg. ES-Reward: 0.3366 | DisLoss: 1.3501 | Expert Scores: 0.7617 | Policy Scores: 0.3319
#
# [Generation 182/200] - Time: 4:34 - Estimated Finish: 26.07.2025 01:51:34
# Predator | Avg. ES-Reward: 0.3351 | DisLoss: 1.4291 | Expert Scores: 0.8207 | Policy Scores: 0.3071
# Prey     | Avg. ES-Reward: 0.4098 | DisLoss: 1.3365 | Expert Scores: 0.7627 | Policy Scores: 0.3124
#
# [Generation 183/200] - Time: 4:36 - Estimated Finish: 26.07.2025 01:52:13
# Predator | Avg. ES-Reward: 0.3398 | DisLoss: 1.4201 | Expert Scores: 0.8137 | Policy Scores: 0.3577
# Prey     | Avg. ES-Reward: 0.3841 | DisLoss: 1.2995 | Expert Scores: 0.7613 | Policy Scores: 0.3239
#
# [Generation 184/200] - Time: 4:25 - Estimated Finish: 26.07.2025 01:49:17
# Predator | Avg. ES-Reward: 0.3113 | DisLoss: 1.4321 | Expert Scores: 0.8235 | Policy Scores: 0.3416
# Prey     | Avg. ES-Reward: 0.3324 | DisLoss: 1.3003 | Expert Scores: 0.7599 | Policy Scores: 0.3145
#
# [Generation 185/200] - Time: 4:25 - Estimated Finish: 26.07.2025 01:49:08
# Predator | Avg. ES-Reward: 0.3313 | DisLoss: 1.3281 | Expert Scores: 0.8271 | Policy Scores: 0.3124
# Prey     | Avg. ES-Reward: 0.3567 | DisLoss: 1.2583 | Expert Scores: 0.7566 | Policy Scores: 0.2656
#
# [Generation 186/200] - Time: 4:24 - Estimated Finish: 26.07.2025 01:48:57
# Predator | Avg. ES-Reward: 0.3350 | DisLoss: 1.3186 | Expert Scores: 0.8278 | Policy Scores: 0.2975
# Prey     | Avg. ES-Reward: 0.3788 | DisLoss: 1.3524 | Expert Scores: 0.7548 | Policy Scores: 0.2948
#
# [Generation 187/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:50:29
# Predator | Avg. ES-Reward: 0.3269 | DisLoss: 1.4116 | Expert Scores: 0.8351 | Policy Scores: 0.3136
# Prey     | Avg. ES-Reward: 0.3950 | DisLoss: 1.4206 | Expert Scores: 0.7613 | Policy Scores: 0.3279
#
# [Generation 188/200] - Time: 4:21 - Estimated Finish: 26.07.2025 01:48:28
# Predator | Avg. ES-Reward: 0.2962 | DisLoss: 1.3950 | Expert Scores: 0.8040 | Policy Scores: 0.3489
# Prey     | Avg. ES-Reward: 0.3469 | DisLoss: 1.5350 | Expert Scores: 0.7648 | Policy Scores: 0.3641
#
# [Generation 189/200] - Time: 4:26 - Estimated Finish: 26.07.2025 01:49:26
# Predator | Avg. ES-Reward: 0.2742 | DisLoss: 1.2570 | Expert Scores: 0.8228 | Policy Scores: 0.3173
# Prey     | Avg. ES-Reward: 0.3536 | DisLoss: 1.5902 | Expert Scores: 0.7544 | Policy Scores: 0.3400
#
# [Generation 190/200] - Time: 4:25 - Estimated Finish: 26.07.2025 01:49:15
# Predator | Avg. ES-Reward: 0.3067 | DisLoss: 1.3333 | Expert Scores: 0.8193 | Policy Scores: 0.3280
# Prey     | Avg. ES-Reward: 0.3135 | DisLoss: 1.5534 | Expert Scores: 0.7580 | Policy Scores: 0.3571
#
# [Generation 191/200] - Time: 5:03 - Estimated Finish: 26.07.2025 01:55:35
# Predator | Avg. ES-Reward: 0.2513 | DisLoss: 1.3279 | Expert Scores: 0.8345 | Policy Scores: 0.3179
# Prey     | Avg. ES-Reward: 0.3470 | DisLoss: 1.5560 | Expert Scores: 0.7507 | Policy Scores: 0.3238
#
# [Generation 192/200] - Time: 6:02 - Estimated Finish: 26.07.2025 02:04:21
# Predator | Avg. ES-Reward: 0.2741 | DisLoss: 1.3327 | Expert Scores: 0.8179 | Policy Scores: 0.3406
# Prey     | Avg. ES-Reward: 0.2806 | DisLoss: 1.4903 | Expert Scores: 0.7593 | Policy Scores: 0.3306
#
# [Generation 193/200] - Time: 4:25 - Estimated Finish: 26.07.2025 01:51:32
# Predator | Avg. ES-Reward: 0.2606 | DisLoss: 1.4219 | Expert Scores: 0.8294 | Policy Scores: 0.3571
# Prey     | Avg. ES-Reward: 0.2822 | DisLoss: 1.4827 | Expert Scores: 0.7558 | Policy Scores: 0.3200
#
# [Generation 194/200] - Time: 4:34 - Estimated Finish: 26.07.2025 01:52:33
# Predator | Avg. ES-Reward: 0.2695 | DisLoss: 1.3220 | Expert Scores: 0.8109 | Policy Scores: 0.2644
# Prey     | Avg. ES-Reward: 0.3509 | DisLoss: 1.4661 | Expert Scores: 0.7647 | Policy Scores: 0.3373
#
# [Generation 195/200] - Time: 4:39 - Estimated Finish: 26.07.2025 01:53:01
# Predator | Avg. ES-Reward: 0.2833 | DisLoss: 1.3019 | Expert Scores: 0.8120 | Policy Scores: 0.3632
# Prey     | Avg. ES-Reward: 0.3368 | DisLoss: 1.4675 | Expert Scores: 0.7654 | Policy Scores: 0.3137
#
# [Generation 196/200] - Time: 4:39 - Estimated Finish: 26.07.2025 01:53:03
# Predator | Avg. ES-Reward: 0.3090 | DisLoss: 1.2929 | Expert Scores: 0.8156 | Policy Scores: 0.3195
# Prey     | Avg. ES-Reward: 0.3290 | DisLoss: 1.4661 | Expert Scores: 0.7693 | Policy Scores: 0.3741
#
# [Generation 197/200] - Time: 4:31 - Estimated Finish: 26.07.2025 01:52:31
# Predator | Avg. ES-Reward: 0.3013 | DisLoss: 1.3321 | Expert Scores: 0.8465 | Policy Scores: 0.3266
# Prey     | Avg. ES-Reward: 0.4088 | DisLoss: 1.3890 | Expert Scores: 0.7684 | Policy Scores: 0.3008
#
# [Generation 198/200] - Time: 4:35 - Estimated Finish: 26.07.2025 01:52:41
# Predator | Avg. ES-Reward: 0.3355 | DisLoss: 1.2922 | Expert Scores: 0.8282 | Policy Scores: 0.3158
# Prey     | Avg. ES-Reward: 0.2671 | DisLoss: 1.3110 | Expert Scores: 0.7680 | Policy Scores: 0.3268
#
# [Generation 199/200] - Time: 4:25 - Estimated Finish: 26.07.2025 01:52:22
# Predator | Avg. ES-Reward: 0.3268 | DisLoss: 1.3351 | Expert Scores: 0.8375 | Policy Scores: 0.3298
# Prey     | Avg. ES-Reward: 0.3545 | DisLoss: 1.2582 | Expert Scores: 0.7642 | Policy Scores: 0.2830
#
# [Generation 200/200] - Time: 4:33 - Estimated Finish: 26.07.2025 01:52:30
# Predator | Avg. ES-Reward: 0.3797 | DisLoss: 1.3712 | Expert Scores: 0.8234 | Policy Scores: 0.3203
# Prey     | Avg. ES-Reward: 0.3911 | DisLoss: 1.2440 | Expert Scores: 0.7698 | Policy Scores: 0.2888
#
# Models successfully saved!
# Training done!
