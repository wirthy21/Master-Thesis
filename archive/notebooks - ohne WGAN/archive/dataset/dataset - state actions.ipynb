# %%
import os
import cv2
import torch
import numpy as np
import pandas as pd
from ultralytics import YOLO
from collections import defaultdict
from deep_sort_realtime.deepsort_tracker import DeepSort
from utils.dataset_utils import get_swarm_data, get_quality_score, get_full_tracks, get_tensor, group_and_save_tensors, get_state_actions, group_and_save_state_actions

# %%
# References: 
# https://learnopencv.com/real-time-deep-sort-with-torchvision-detectors/#Real-Time-Deep-SORT-Setup
# https://pypi.org/project/deep-sort-realtime/

# %%
raw_video_folder = r'C:\Users\janni\OneDrive\Dokumente\Privat\Bildung\M. Sc. Social and Economic Data Science\4. Semester\Master Thesis\Code\data\raw\videos'
yolo_path = r'C:\Users\janni\OneDrive\Dokumente\Privat\Bildung\M. Sc. Social and Economic Data Science\4. Semester\Master Thesis\Code\models\costumized_yolo\costumized_yolo\costumized_yolo.pt'
output_folder = r'C:\Users\janni\OneDrive\Dokumente\Privat\Bildung\M. Sc. Social and Economic Data Science\4. Semester\Master Thesis\Code\data\processed\state_actions'

# %%
# Inputs
video = "video_5s" #60 min
clip_size = 10

# %%
video_path = raw_video_folder + "\\" + video + ".mp4"
cap = cv2.VideoCapture(video_path)

fps = cap.get(cv2.CAP_PROP_FPS)
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
duration = total_frames / fps
total_traj = round(total_frames / clip_size)

print(f"FPS: {fps}")
print(f"Total frames: {total_frames}")
print(f"Duration (s): {duration:.2f}")
print(f"Total trajectories: {total_traj}")
print("Prey Count: 32")
print("Predator Count: 1")
# Out:
# FPS: 30.0
# Total frames: 153
# Duration (s): 5.10
# Total trajectories: 15
# Prey Count: 32
# Predator Count: 1

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = YOLO(yolo_path)
tracker = DeepSort(max_age=5)

video_idx = 0
frame_idx = 0
tensor_data = []

while True:
    frames = []
    for i in range(clip_size):
        success, frame = cap.read()
        if not success:
            break
        frames.append(frame)

    if not frames:
        break
    
    results = []

    for frame in frames:
        df = get_swarm_data(frame, model, tracker, frame_idx)
        results.append(df)
        frame_idx += 1

    combined_df = pd.concat(results, ignore_index=True)
    mean_track_visibility, num_full_tracks, mean_confidence = get_quality_score(combined_df, n=clip_size)
    video_idx += 1
    
    full_tracks_df = get_full_tracks(combined_df, n=clip_size)

    if not full_tracks_df.empty:
        tensor_data.append(get_state_actions(full_tracks_df))

cap.release()

group_and_save_state_actions(video, tensor_data, output_folder)
# Out:
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 814.1ms
# Speed: 20.3ms preprocess, 814.1ms inference, 2.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 1262.4ms
# Speed: 20.6ms preprocess, 1262.4ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 1162.3ms
# Speed: 24.1ms preprocess, 1162.3ms inference, 2.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 790.8ms
# Speed: 19.7ms preprocess, 790.8ms inference, 2.5ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 729.1ms
# Speed: 23.7ms preprocess, 729.1ms inference, 3.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 711.5ms
# Speed: 20.7ms preprocess, 711.5ms inference, 2.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 680.6ms
# Speed: 16.7ms preprocess, 680.6ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 627.1ms
# Speed: 11.4ms preprocess, 627.1ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 610.0ms
# Speed: 19.8ms preprocess, 610.0ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 617.2ms
# Speed: 20.4ms preprocess, 617.2ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 7.526315789473684
# Number of full tracks: 0
# Mean confidence: 0.7258825054518262
# No full tracks found.
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 614.6ms
# Speed: 12.6ms preprocess, 614.6ms inference, 4.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 603.3ms
# Speed: 16.6ms preprocess, 603.3ms inference, 3.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 616.8ms
# Speed: 16.1ms preprocess, 616.8ms inference, 2.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 615.9ms
# Speed: 17.4ms preprocess, 615.9ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 604.8ms
# Speed: 16.4ms preprocess, 604.8ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 605.4ms
# Speed: 18.5ms preprocess, 605.4ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 609.2ms
# Speed: 15.9ms preprocess, 609.2ms inference, 2.5ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 609.6ms
# Speed: 16.3ms preprocess, 609.6ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 605.4ms
# Speed: 16.8ms preprocess, 605.4ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys,