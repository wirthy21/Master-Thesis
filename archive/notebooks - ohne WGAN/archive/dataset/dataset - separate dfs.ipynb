# %%
import os
import cv2
import torch
import math
import numpy as np
import pandas as pd
from ultralytics import YOLO
from collections import defaultdict
from deep_sort_realtime.deepsort_tracker import DeepSort
from utils.dataset_utils import get_swarm_data, get_quality_score, get_full_tracks, get_state_actions, get_specific_states_actions, shape_action_tensors, shape_state_tensors, save_state_action_tensors

# %%
# Analyse des Attention Network, wie viele lokalen Nachbarn werden wie einbezogen?
# - Referenzen das 1 - 2 nach Nachbarn reichen, oder 2-fache Fischlänge
# - So kann auch die Death-Rate ermittelt werden, aus Predator sicht die gewichte der Fische interpretieren

# References: 
# https://learnopencv.com/real-time-deep-sort-with-torchvision-detectors/#Real-Time-Deep-SORT-Setup
# https://pypi.org/project/deep-sort-realtime/

# Vergleich mit Daten aus Kalifornien und Analyse des Lebenstriebs

# %%
# Inputs
video = "video_5s"
clip_size = 10
num_fish = 33

# %%
raw_video_folder = r'..\data\raw\videos'
yolo_path = f'..\models\costumized_yolo\costumized_yolo\costumized_yolo.pt'
processed_video_folder = f'..\data\processed\{video}'
# Out:
# <string>:3: SyntaxWarning: invalid escape sequence '\{'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\{'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <string>:3: SyntaxWarning: invalid escape sequence '\{'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\{'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\janni\AppData\Local\Temp\ipykernel_17460\1604442491.py:2: SyntaxWarning: invalid escape sequence '\m'
#   yolo_path = f'..\models\costumized_yolo\costumized_yolo\costumized_yolo.pt'
# C:\Users\janni\AppData\Local\Temp\ipykernel_17460\1604442491.py:3: SyntaxWarning: invalid escape sequence '\{'
#   processed_video_folder = f'..\data\processed\{video}'
# C:\Users\janni\AppData\Local\Temp\ipykernel_17460\1604442491.py:3: SyntaxWarning: invalid escape sequence '\d'
#   processed_video_folder = f'..\data\processed\{video}'

# %%
video_path = raw_video_folder + "\\" + video + ".mp4"
cap = cv2.VideoCapture(video_path)

fps = cap.get(cv2.CAP_PROP_FPS)
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
duration = total_frames / fps
total_traj = total_frames - clip_size + 1

print(f"FPS: {fps}")
print(f"Total frames: {total_frames}")
print(f"Duration (s): {duration:.2f}")
print(f"Total trajectories: {total_traj}")
print("Prey Count: 32")
print("Predator Count: 1")
# Out:
# FPS: 30.0
# Total frames: 153
# Duration (s): 5.10
# Total trajectories: 144
# Prey Count: 32
# Predator Count: 1

# %%
device  = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model   = YOLO(yolo_path)
tracker = DeepSort(max_age=5)

video_idx   = 0
threshold = num_fish * 0.75

raw_path = os.path.join(processed_video_folder, "state_actions", "raw")
os.makedirs(raw_path, exist_ok=True)

for start_frame in range(total_traj):
    end_frame = start_frame + clip_size - 1
    print(f"[Clip {video_idx}] Startframe: {start_frame}, Endframe: {end_frame}")

    cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

    frames = []
    for _ in range(clip_size):
        success, frame = cap.read()
        if not success:
            break
        frames.append(frame)
    if len(frames) < clip_size:
        break

    dfs = []
    for offset, frame in enumerate(frames):
        frame_idx = start_frame + offset
        df = get_swarm_data(frame, model, tracker, frame_idx)
        dfs.append(df)

    combined_df = pd.concat(dfs, ignore_index=True)

    mean_track_visibility, num_full_tracks, mean_confidence = get_quality_score(combined_df, n=clip_size)
    video_idx += 1

    full_tracks_df = get_full_tracks(combined_df, clip_size)

    num_tracks = int(len(full_tracks_df) / clip_size)
    
    if num_tracks > threshold:
        df_state_actions = get_state_actions(full_tracks_df)
        df_state_actions.to_csv(os.path.join(raw_path, f"{video_idx}_{video}_{num_tracks}_state_actions.csv"), index=False)

cap.release()
# Out:
# [Clip 0] Startframe: 0, Endframe: 9
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 63.9ms
# Speed: 7.8ms preprocess, 63.9ms inference, 3.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 14.8ms
# Speed: 5.0ms preprocess, 14.8ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 12.4ms
# Speed: 4.9ms preprocess, 12.4ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 12.2ms
# Speed: 4.6ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 13.7ms
# Speed: 5.6ms preprocess, 13.7ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 14.5ms
# Speed: 4.7ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 12.3ms
# Speed: 4.7ms preprocess, 12.3ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 11.7ms
# Speed: 4.5ms preprocess, 11.7ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 11.8ms
# Speed: 4.8ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 15.1ms
# Speed: 6.5ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 7.526315789473684
# Number of full tracks: 0
# Mean confidence: 0.7258211484080866
# No full tracks found.
# [Clip 1] Startframe: 1, Endframe: 10
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 12.2ms
# Speed: 4.6ms preprocess, 12.2ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 11.8ms
# Speed: 5.4ms preprocess, 11.8ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 11.3ms
# Speed: 4.7ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 11.7ms
# Speed: 6.7ms preprocess, 11.7ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 15.9ms
# Speed: 6.5ms preprocess, 15.9ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 11.4ms
# Speed: 8.1ms preprocess, 11.4ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 14.9ms
# Speed: 6.6ms preprocess, 14.9ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 12.4ms
# Speed: 4.7ms preprocess, 12.4ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 12.0ms
# Speed: 4.7ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 12.1ms
# Speed: 5.3ms preprocess, 12.1ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 8.41304347826087
# Number of full tracks: 28
# Mean confidence: 0.7230272538194032
# [Clip 2] Startframe: 2, Endframe: 11
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 21.3ms
# Speed: 5.0ms preprocess, 21.3ms inference, 8.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 15.2ms
# Speed: 4.9ms preprocess, 15.2ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 12.5ms
# Speed: 6.1ms preprocess, 12.5ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 12.1ms
# Speed: 6.4ms preprocess, 12.1ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 11.8ms
# Speed: 5.1ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 15.0ms
# Speed: 7.0ms preprocess, 15.0ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 19.1ms
# Speed: 5.5ms preprocess, 19.1ms inference, 4.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 12.1ms
# Speed: 5.5ms preprocess, 12.1ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 11.4ms
# Speed: 5.8ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 11.9ms
# Speed: 5.0ms preprocess, 11.9ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 8.333333333333334
# Number of full tracks: 29
# Mean confidence: 0.7260112279320355
# [Clip 3] Startframe: 3, Endframe: 12
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 21.9ms
# Speed: 5.8ms preprocess, 21.9ms inference, 6.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 15.4ms
# Speed: 6.3ms preprocess, 15.4ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 14.0ms
# Speed: 7.1ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 14.4ms
# Speed: 5.1ms preprocess, 14.4ms inference, 2.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 14.1ms
# Speed: 6.4ms preprocess, 14.1ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 15.7ms
# Speed: 6.8ms preprocess, 15.7ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 13.1ms
# Speed: 5.0ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 12.5ms
# Speed: 4.7ms preprocess, 12.5ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 10.5ms
# Speed: 4.9ms preprocess, 10.5ms inference, 2.5ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 14.5ms
# Speed: 6.7ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 8.477272727272727
# Number of full tracks: 28
# Mean confidence: 0.7257789506376544
# [Clip 4] Startframe: 4, Endframe: 13
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 11.4ms
# Speed: 4.8ms preprocess, 11.4ms inference, 4.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 12.2ms
# Speed: 5.0ms preprocess, 12.2ms inference, 2.5ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 14.6ms
# Speed: 6.8ms preprocess, 14.6ms inference, 2.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 13.7ms
# Speed: 6.8ms preprocess, 13.7ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 12.8ms
# Speed: 4.9ms preprocess, 12.8ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 14.5ms
# Speed: 6.7ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 16.3ms
# Speed: 5.0ms preprocess, 16.3ms inference, 3.5ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 13.1ms
# Speed: 5.0ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 11.6ms
# Speed: 4.8ms preprocess, 11.6ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 12.2ms
# Speed: 4.8ms preprocess, 12.2ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 8.042553191489361
# Number of full tracks: 25
# Mean confidence: 0.7268734064541365
# [Clip 5] Startframe: 5, Endframe: 14
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 10.8ms
# Speed: 5.1ms preprocess, 10.8ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 11.4ms
# Speed: 5.1ms preprocess, 11.4ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 12.2ms
# Speed: 4.9ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 13.6ms
# Speed: 6.1ms preprocess, 13.6ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 13.4ms
# Speed: 6.7ms preprocess, 13.4ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 14.7ms
# Speed: 6.6ms preprocess, 14.7ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 11
ms preprocess, 18.0ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 6.648148148148148
# Number of full tracks: 11
# Mean confidence: 0.6751509882321879
# [Clip 136] Startframe: 136, Endframe: 145
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 16.1ms
# Speed: 7.7ms preprocess, 16.1ms inference, 3.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 20.8ms
# Speed: 5.6ms preprocess, 20.8ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 15.2ms
# Speed: 4.9ms preprocess, 15.2ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 22.5ms
# Speed: 5.3ms preprocess, 22.5ms inference, 3.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 19.9ms
# Speed: 6.6ms preprocess, 19.9ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 15.7ms
# Speed: 5.0ms preprocess, 15.7ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 15.8ms
# Speed: 6.4ms preprocess, 15.8ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 15.8ms
# Speed: 7.0ms preprocess, 15.8ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 15.7ms
# Speed: 5.3ms preprocess, 15.7ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 20.1ms
# Speed: 5.7ms preprocess, 20.1ms inference, 3.3ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 6.75
# Number of full tracks: 8
# Mean confidence: 0.6748060661813488
# [Clip 137] Startframe: 137, Endframe: 146
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 17.2ms
# Speed: 4.9ms preprocess, 17.2ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 17.3ms
# Speed: 5.0ms preprocess, 17.3ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 17.5ms
# Speed: 5.3ms preprocess, 17.5ms inference, 2.5ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 16.0ms
# Speed: 5.3ms preprocess, 16.0ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 16.0ms
# Speed: 4.9ms preprocess, 16.0ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 16.1ms
# Speed: 5.0ms preprocess, 16.1ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 16.0ms
# Speed: 5.2ms preprocess, 16.0ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 16.0ms
# Speed: 5.8ms preprocess, 16.0ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 15.0ms
# Speed: 7.1ms preprocess, 15.0ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 18.4ms
# Speed: 5.0ms preprocess, 18.4ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 6.518518518518518
# Number of full tracks: 7
# Mean confidence: 0.6748513374972133
# [Clip 138] Startframe: 138, Endframe: 147
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 14.5ms
# Speed: 5.0ms preprocess, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 14.4ms
# Speed: 7.0ms preprocess, 14.4ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 14.4ms
# Speed: 6.8ms preprocess, 14.4ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 14.4ms
# Speed: 5.0ms preprocess, 14.4ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 14.6ms
# Speed: 5.0ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 14.6ms
# Speed: 5.0ms preprocess, 14.6ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 14.9ms
# Speed: 6.4ms preprocess, 14.9ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 14.8ms
# Speed: 5.3ms preprocess, 14.8ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 14.0ms
# Speed: 5.2ms preprocess, 14.0ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 13.5ms
# Speed: 5.2ms preprocess, 13.5ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 6.25
# Number of full tracks: 5
# Mean confidence: 0.6729148901425875
# [Clip 139] Startframe: 139, Endframe: 148
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 14.1ms
# Speed: 4.6ms preprocess, 14.1ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 14.3ms
# Speed: 5.2ms preprocess, 14.3ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 15.4ms
# Speed: 7.3ms preprocess, 15.4ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 14.1ms
# Speed: 4.9ms preprocess, 14.1ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 14.3ms
# Speed: 5.5ms preprocess, 14.3ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 15.1ms
# Speed: 7.4ms preprocess, 15.1ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 13.8ms
# Speed: 5.0ms preprocess, 13.8ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 13.7ms
# Speed: 5.0ms preprocess, 13.7ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 20.4ms
# Speed: 5.0ms preprocess, 20.4ms inference, 2.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 12.5ms
# Speed: 6.9ms preprocess, 12.5ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 6.4363636363636365
# Number of full tracks: 6
# Mean confidence: 0.6637135995132429
# [Clip 140] Startframe: 140, Endframe: 149
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 12.4ms
# Speed: 4.9ms preprocess, 12.4ms inference, 2.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 13.5ms
# Speed: 6.3ms preprocess, 13.5ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 41.1ms
# Speed: 5.3ms preprocess, 41.1ms inference, 2.5ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 13.6ms
# Speed: 5.1ms preprocess, 13.6ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 22.8ms
# Speed: 5.0ms preprocess, 22.8ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 13.5ms
# Speed: 7.0ms preprocess, 13.5ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 15.0ms
# Speed: 7.0ms preprocess, 15.0ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 15.1ms
# Speed: 7.0ms preprocess, 15.1ms inference, 4.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 16.0ms
# Speed: 4.9ms preprocess, 16.0ms inference, 2.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 15.6ms
# Speed: 6.6ms preprocess, 15.6ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 6.634615384615385
# Number of full tracks: 8
# Mean confidence: 0.6556227272539809
# [Clip 141] Startframe: 141, Endframe: 150
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 16.1ms
# Speed: 8.0ms preprocess, 16.1ms inference, 4.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 15.9ms
# Speed: 5.0ms preprocess, 15.9ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 16.5ms
# Speed: 6.2ms preprocess, 16.5ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 16.2ms
# Speed: 5.0ms preprocess, 16.2ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 16.4ms
# Speed: 7.3ms preprocess, 16.4ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 16.4ms
# Speed: 9.1ms preprocess, 16.4ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 16.2ms
# Speed: 5.1ms preprocess, 16.2ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 16.3ms
# Speed: 4.9ms preprocess, 16.3ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 15.4ms
# Speed: 5.5ms preprocess, 15.4ms inference, 3.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 16.7ms
# Speed: 5.0ms preprocess, 16.7ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 6.6415094339622645
# Number of full tracks: 6
# Mean confidence: 0.6427739184432559
# [Clip 142] Startframe: 142, Endframe: 151
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 17.4ms
# Speed: 4.8ms preprocess, 17.4ms inference, 4.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 18.3ms
# Speed: 5.3ms preprocess, 18.3ms inference, 3.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 15.8ms
# Speed: 8.2ms preprocess, 15.8ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 26.2ms
# Speed: 5.5ms preprocess, 26.2ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 15.0ms
# Speed: 5.2ms preprocess, 15.0ms inference, 3.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 22.3ms
# Speed: 4.9ms preprocess, 22.3ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 14.8ms
# Speed: 5.5ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 15.7ms
# Speed: 5.0ms preprocess, 15.7ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 15.0ms
# Speed: 6.8ms preprocess, 15.0ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 14.6ms
# Speed: 4.9ms preprocess, 14.6ms inference, 2.8ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 6.363636363636363
# Number of full tracks: 3
# Mean confidence: 0.6356225763597796
# [Clip 143] Startframe: 143, Endframe: 152
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 15.1ms
# Speed: 4.6ms preprocess, 15.1ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 15.2ms
# Speed: 5.1ms preprocess, 15.2ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 15.1ms
# Speed: 7.2ms preprocess, 15.1ms inference, 2.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 15.1ms
# Speed: 5.5ms preprocess, 15.1ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 15.1ms
# Speed: 5.4ms preprocess, 15.1ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 13.8ms
# Speed: 5.0ms preprocess, 13.8ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 15.0ms
# Speed: 5.1ms preprocess, 15.0ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 14.9ms
# Speed: 4.9ms preprocess, 14.9ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 17.2ms
# Speed: 5.1ms preprocess, 17.2ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 15.1ms
# Speed: 7.3ms preprocess, 15.1ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
# Mean track visibility: 6.293103448275862
# Number of full tracks: 5
# Mean confidence: 0.6224062792923418

# %%
raw_path = os.path.join(processed_video_folder, "state_actions", "raw")
os.makedirs(raw_path, exist_ok=True)

for name in os.listdir(raw_path):
    file_path = os.path.join(raw_path, name)
    df_full = pd.read_csv(file_path)

    n_agents = df['agent_id'].nunique()

    df_pred_prey = get_specific_states_actions(df_full, "Predator Head", "Prey")
    df_prey_prey = get_specific_states_actions(df_full, "Prey", "Prey")
    df_prey_pred = get_specific_states_actions(df_full, "Prey" ,"Predator Head")

    state_actions_path = os.path.join(processed_video_folder, "state_actions")
    os.makedirs(state_actions_path, exist_ok=True)

    dfs = [("df_full", df_full),
           ("df_pred_prey", df_pred_prey),
           ("df_prey_prey", df_prey_prey),
           ("df_prey_pred", df_prey_pred),]

    for name, df in dfs:
        folder_path = os.path.join(state_actions_path, name)
        os.makedirs(folder_path, exist_ok=True)

        state_tensors = []
        action_tensors = []

        for i in df.iloc():
            state_array = df[['dx', 'dy', 'rel_v_x', 'rel_v_y']].to_numpy(dtype=np.float32)
            action_array = df['theta'].to_numpy(dtype=np.float32)

            state_tensor = torch.from_numpy(state_array)
            action_tensor = torch.from_numpy(action_array).unsqueeze(1)

            state_tensors.append(state_tensor)
            action_tensors.append(action_tensor)

        # Change format
        states = shape_state_tensors(state_tensors) # (batch, n_pairs, seq_len, state_dim)
        actions = shape_action_tensors(action_tensors) # (batch, n_pairs, seq_len, action_dim)

        torch.save(states,  os.path.join(folder_path, f"(Agents {n_agents})_{name}_states.pt"))
        torch.save(actions, os.path.join(folder_path, f"(Agents {n_agents})_{name}_actions.pt"))
