# %%
import cv2
import pandas as pd
import os
from ultralytics import YOLO

# %%
raw_video_folder = r'C:\Users\janni\OneDrive\Dokumente\Privat\Bildung\M. Sc. Social and Economic Data Science\4. Semester\Master Thesis\Code\data\raw\videos'
yolo_path      = r'C:\Users\janni\OneDrive\Dokumente\Privat\Bildung\M. Sc. Social and Economic Data Science\4. Semester\Master Thesis\Code\models\costumized_yolo\costumized_yolo\costumized_yolo.pt'
output_folder    = r'C:\Users\janni\OneDrive\Dokumente\Privat\Bildung\M. Sc. Social and Economic Data Science\4. Semester\Master Thesis\Code\data\processed'

# %%
model = YOLO(yolo_path)
video = "video_5s"
video_path = raw_video_folder + "\\" + video + ".mp4"
cap = cv2.VideoCapture(video_path)

fps = cap.get(cv2.CAP_PROP_FPS)
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
duration = total_frames / fps

print(f"FPS: {fps}")
print(f"Total frames: {total_frames}")
print(f"Duration (s): {duration:.2f}")
print("Prey Count: 32")
print("Predator Count: 1")
# Out:
# FPS: 30.0
# Total frames: 153
# Duration (s): 5.10
# Prey Count: 32
# Predator Count: 1

# %%
'''VISUAL MODEL REPRESENTATION'''

label_colors = {
    "Predator Head": (0, 0, 255),
    "Predator":      (0, 102, 255),
    "Prey Head":     (255, 0, 0),
    "Prey":          (255, 153, 102),
}

frame_number = 0

while True:
    success, frame = cap.read()
    if not success:
        break

    # Inferenz
    results = model(frame, conf=0.2)
    boxes = results[0].boxes

    for box in boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        cx, cy       = (x1 + x2)//2, (y1 + y2)//2
        cls_id       = int(box.cls[0])
        label        = model.names[cls_id]
        color        = label_colors.get(label, (255, 255, 255))

        # Bounding-Box und Centroid zeichnen
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
        cv2.circle(frame, (cx, cy), 3, (0, 0, 255), -1)

    frame_number += 1

    # Fenstergröße anpassen und anzeigen
    annotated_frame = cv2.resize(frame, (720, 720))
    cv2.imshow("YOLO Detection", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Aufräumen
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 705.5ms
# Speed: 19.2ms preprocess, 705.5ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 781.0ms
# Speed: 28.9ms preprocess, 781.0ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 651.4ms
# Speed: 16.1ms preprocess, 651.4ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)

# %%
#Prey: 32
#Predator: 1

def process_video(video):
    video_path = os.path.join(raw_video_folder, f"{video}.mp4")
    cap = cv2.VideoCapture(video_path)
    centroids_data = []
    frame_number = 0

    while True:
        success, frame = cap.read()
        if not success:
            break

        # Inferenz
        results = model(frame, conf=0.3) # based on observation

        for box in results[0].boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cx = (x1 + x2) // 2
            cy = (y1 + y2) // 2

            cls_id = int(box.cls[0])
            label = model.names[cls_id]
            conf = float(box.conf[0])

            # Daten speichern
            centroids_data.append({
                "frame": frame_number,
                "label": label,
                "confidence": conf,
                "x": cx,
                "y": cy
            })

        frame_number += 1

    cap.release()

    # DataFrame und Export
    movement_data = pd.DataFrame(centroids_data)
    output_path = os.path.join(output_folder, f"movement_data_{video}.csv")
    movement_data.to_csv(output_path, index=False)
    
    return movement_data

# %%
movement_data = process_video(video)
movement_data
# Out:
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 932.1ms
# Speed: 28.6ms preprocess, 932.1ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 779.7ms
# Speed: 19.7ms preprocess, 779.7ms inference, 2.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 866.5ms
# Speed: 31.0ms preprocess, 866.5ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 771.5ms
# Speed: 22.9ms preprocess, 771.5ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 741.6ms
# Speed: 31.1ms preprocess, 741.6ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 715.8ms
# Speed: 15.6ms preprocess, 715.8ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 769.1ms
# Speed: 72.0ms preprocess, 769.1ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 1972.2ms
# Speed: 17.2ms preprocess, 1972.2ms inference, 6.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 1035.0ms
# Speed: 35.1ms preprocess, 1035.0ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 971.6ms
# Speed: 15.8ms preprocess, 971.6ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 934.4ms
# Speed: 24.1ms preprocess, 934.4ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 1108.9ms
# Speed: 20.4ms preprocess, 1108.9ms inference, 9.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 828.1ms
# Speed: 11.4ms preprocess, 828.1ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 798.1ms
# Speed: 19.9ms preprocess, 798.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 801.7ms
# Speed: 19.2ms preprocess, 801.7ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 836.5ms
# Speed: 18.6ms preprocess, 836.5ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 820.0ms
# Speed: 19.7ms preprocess, 820.0ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 31 Preys, 814.5ms
# Speed: 14.9ms preprocess, 814.5ms inference, 3.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 806.9ms
# Speed: 17.5ms preprocess, 806.9ms inference, 3.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 813.7ms
# Speed: 26.1ms preprocess, 813.7ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 33 Preys, 854.2ms
# Speed: 23.1ms preprocess, 854.2ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 815.3ms
# Speed: 17.2ms preprocess, 815.3ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 993.3ms
# Speed: 18.7ms preprocess, 993.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 832.3ms
# Speed: 16.9ms preprocess, 832.3ms inference, 2.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 1093.8ms
# Speed: 20.1ms preprocess, 1093.8ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 28 Preys, 839.1ms
# Speed: 13.8ms preprocess, 839.1ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 847.0ms
# Speed: 17.7ms preprocess, 847.0ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 838.8ms
# Speed: 19.8ms preprocess, 838.8ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 803.9ms
# Speed: 24.5ms preprocess, 803.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 811.8ms
# Speed: 18.7ms preprocess, 811.8ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 804.4ms
# Speed: 24.0ms preprocess, 804.4ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 873.9ms
# Speed: 20.7ms preprocess, 873.9ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 844.1ms
# Speed: 18.9ms preprocess, 844.1ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 818.0ms
# Speed: 16.0ms preprocess, 818.0ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 806.5ms
# Speed: 22.5ms preprocess, 806.5ms inference, 2.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 794.5ms
# Speed: 18.9ms preprocess, 794.5ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 798.0ms
# Speed: 17.3ms preprocess, 798.0ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 1087.9ms
# Speed: 22.8ms preprocess, 1087.9ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 791.4ms
# Speed: 16.2ms preprocess, 791.4ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 33 Preys, 794.3ms
# Speed: 25.0ms preprocess, 794.3ms inference, 3.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 33 Preys, 806.1ms
# Speed: 18.7ms preprocess, 806.1ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 30 Preys, 1012.1ms
# Speed: 20.3ms preprocess, 1012.1ms inference, 8.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 29 Preys, 851.9ms
# Speed: 24.5ms preprocess, 851.9ms inference, 5.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 32 Preys, 821.3ms
# Speed: 16.0ms preprocess, 821.3ms inference, 2.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 31 Preys, 781.3ms
# Speed: 19.4ms preprocess, 781.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 30 Preys, 788.9ms
# Speed: 15.5ms preprocess, 788.9ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 30 Preys, 802.2ms
# Speed: 19.0ms preprocess, 802.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 29 Preys, 801.6ms
# Speed: 28.3ms preprocess, 801.6ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 31 Preys, 809.5ms
# Speed: 31.6ms preprocess, 809.5ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 29 Preys, 1075.9ms
# Speed: 16.0ms preprocess, 1075.9ms inference, 3.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 29 Preys, 818.7ms
# Speed: 25.4ms preprocess, 818.7ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 29 Preys, 812.1ms
# Speed: 15.8ms preprocess, 812.1ms inference, 2.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 29 Preys, 855.8ms
# Speed: 18.0ms preprocess, 855.8ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 31 Preys, 843.8ms
# Speed: 19.2ms preprocess, 843.8ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 827.6ms
# Speed: 16.7ms preprocess, 827.6ms inference, 2.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 30 Preys, 827.7ms
# Speed: 17.2ms preprocess, 827.7ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 781.4ms
# Speed: 20.6ms preprocess, 781.4ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 793.8ms
# Speed: 16.8ms preprocess, 793.8ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 790.9ms
# Speed: 22.8ms preprocess, 790.9ms inference, 3.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 820.9ms
# Speed: 19.4ms preprocess, 820.9ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 30 Preys, 1015.9ms
# Speed: 16.1ms preprocess, 1015.9ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 29 Preys, 791.2ms
# Speed: 22.0ms preprocess, 791.2ms inference, 6.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 2 Predator Heads, 31 Preys, 1063.0ms
# Speed: 11.9ms preprocess, 1063.0ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 2 Predator Heads, 31 Preys, 887.9ms
# Speed: 16.5ms preprocess, 887.9ms inference, 3.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 2 Predator Heads, 32 Preys, 809.7ms
# Speed: 19.2ms preprocess, 809.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 2 Predator Heads, 30 Preys, 810.6ms
# Speed: 19.2ms preprocess, 810.6ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 795.2ms
# Speed: 16.4ms preprocess, 795.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 31 Preys, 811.8ms
# Speed: 18.4ms preprocess, 811.8ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 817.9ms
# Speed: 16.1ms preprocess, 817.9ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 802.4ms
# Speed: 26.2ms preprocess, 802.4ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 793.9ms
# Speed: 21.5ms preprocess, 793.9ms inference, 4.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 792.1ms
# Speed: 15.7ms preprocess, 792.1ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 28 Preys, 800.7ms
# Speed: 20.5ms preprocess, 800.7ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 28 Preys, 799.9ms
# Speed: 19.6ms preprocess, 799.9ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 28 Preys, 1096.8ms
# Speed: 22.7ms preprocess, 1096.8ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 28 Preys, 812.9ms
# Speed: 20.4ms preprocess, 812.9ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 28 Preys, 830.8ms
# Speed: 15.7ms preprocess, 830.8ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 802.1ms
# Speed: 16.2ms preprocess, 802.1ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 801.1ms
# Speed: 17.1ms preprocess, 801.1ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 983.6ms
# Speed: 17.7ms preprocess, 983.6ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 818.5ms
# Speed: 28.6ms preprocess, 818.5ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 28 Preys, 814.7ms
# Speed: 16.4ms preprocess, 814.7ms inference, 4.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 28 Preys, 788.5ms
# Speed: 20.2ms preprocess, 788.5ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 794.6ms
# Speed: 19.3ms preprocess, 794.6ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 791.9ms
# Speed: 16.5ms preprocess, 791.9ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 843.7ms
# Speed: 18.3ms preprocess, 843.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 813.8ms
# Speed: 11.2ms preprocess, 813.8ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 1053.4ms
# Speed: 19.4ms preprocess, 1053.4ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 778.3ms
# Speed: 15.4ms preprocess, 778.3ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 801.1ms
# Speed: 15.7ms preprocess, 801.1ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 795.2ms
# Speed: 11.2ms preprocess, 795.2ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 32 Preys, 824.5ms
# Speed: 17.9ms preprocess, 824.5ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 33 Preys, 929.4ms
# Speed: 29.5ms preprocess, 929.4ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 32 Preys, 845.4ms
# Speed: 22.8ms preprocess, 845.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 32 Preys, 863.8ms
# Speed: 18.3ms preprocess, 863.8ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 968.9ms
# Speed: 16.4ms preprocess, 968.9ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 32 Preys, 912.6ms
# Speed: 15.1ms preprocess, 912.6ms inference, 2.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 879.6ms
# Speed: 15.0ms preprocess, 879.6ms inference, 3.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 886.5ms
# Speed: 24.9ms preprocess, 886.5ms inference, 6.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 1254.0ms
# Speed: 71.6ms preprocess, 1254.0ms inference, 2.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 889.6ms
# Speed: 19.5ms preprocess, 889.6ms inference, 3.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 816.5ms
# Speed: 24.4ms preprocess, 816.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 833.5ms
# Speed: 13.4ms preprocess, 833.5ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 858.8ms
# Speed: 15.8ms preprocess, 858.8ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 832.0ms
# Speed: 18.0ms preprocess, 832.0ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 852.5ms
# Speed: 17.9ms preprocess, 852.5ms inference, 6.5ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 821.5ms
# Speed: 16.8ms preprocess, 821.5ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 878.9ms
# Speed: 18.4ms preprocess, 878.9ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 822.0ms
# Speed: 15.0ms preprocess, 822.0ms inference, 3.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 34 Preys, 811.1ms
# Speed: 20.0ms preprocess, 811.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 32 Preys, 806.7ms
# Speed: 22.2ms preprocess, 806.7ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 32 Preys, 1084.0ms
# Speed: 15.0ms preprocess, 1084.0ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 32 Preys, 801.3ms
# Speed: 20.8ms preprocess, 801.3ms inference, 3.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 800.6ms
# Speed: 19.6ms preprocess, 800.6ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 32 Preys, 785.1ms
# Speed: 23.9ms preprocess, 785.1ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 787.1ms
# Speed: 14.0ms preprocess, 787.1ms inference, 3.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 800.1ms
# Speed: 22.3ms preprocess, 800.1ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 1073.9ms
# Speed: 16.7ms preprocess, 1073.9ms inference, 3.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 932.8ms
# Speed: 77.8ms preprocess, 932.8ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 775.2ms
# Speed: 21.2ms preprocess, 775.2ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 784.3ms
# Speed: 15.1ms preprocess, 784.3ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 810.9ms
# Speed: 17.5ms preprocess, 810.9ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 786.7ms
# Speed: 17.3ms preprocess, 786.7ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 782.8ms
# Speed: 22.5ms preprocess, 782.8ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 802.4ms
# Speed: 14.4ms preprocess, 802.4ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 923.8ms
# Speed: 127.0ms preprocess, 923.8ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 801.8ms
# Speed: 16.4ms preprocess, 801.8ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 790.8ms
# Speed: 14.8ms preprocess, 790.8ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 770.1ms
# Speed: 30.3ms preprocess, 770.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 794.6ms
# Speed: 16.6ms preprocess, 794.6ms inference, 1.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 822.2ms
# Speed: 24.4ms preprocess, 822.2ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 813.1ms
# Speed: 19.7ms preprocess, 813.1ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 32 Preys, 805.4ms
# Speed: 17.1ms preprocess, 805.4ms inference, 1.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 810.5ms
# Speed: 16.3ms preprocess, 810.5ms inference, 3.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 797.5ms
# Speed: 21.8ms preprocess, 797.5ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 841.4ms
# Speed: 22.5ms preprocess, 841.4ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 27 Preys, 761.0ms
# Speed: 16.6ms preprocess, 761.0ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 903.2ms
# Speed: 67.7ms preprocess, 903.2ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 1130.5ms
# Speed: 15.6ms preprocess, 1130.5ms inference, 3.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 939.3ms
# Speed: 30.0ms preprocess, 939.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 799.7ms
# Speed: 16.5ms preprocess, 799.7ms inference, 1.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 1264.6ms
# Speed: 22.8ms preprocess, 1264.6ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 1641.5ms
# Speed: 18.0ms preprocess, 1641.5ms inference, 4.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 24 Preys, 1172.8ms
# Speed: 37.5ms preprocess, 1172.8ms inference, 3.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 24 Preys, 749.6ms
# Speed: 28.1ms preprocess, 749.6ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 1620.1ms
# Speed: 22.4ms preprocess, 1620.1ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 24 Preys, 759.9ms
# Speed: 16.1ms preprocess, 759.9ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 24 Preys, 828.3ms
# Speed: 21.0ms preprocess, 828.3ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 24 Preys, 1217.3ms
# Speed: 17.9ms preprocess, 1217.3ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 25 Preys, 749.9ms
# Speed: 13.4ms preprocess, 749.9ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 851.5ms
# Speed: 17.1ms preprocess, 851.5ms inference, 2.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 1103.3ms
# Speed: 21.2ms preprocess, 1103.3ms inference, 2.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 26 Preys, 865.6ms
# Speed: 19.5ms preprocess, 865.6ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#       frame label  confidence     x     y
# 0         0  Prey    0.848912   993   852
# 1         0  Prey    0.838825  1270   972
# 2         0  Prey    0.828723  1153   896
# 3         0  Prey    0.824260  1748   748
# 4         0  Prey    0.817484  1234  1033
# ...     ...   ...         ...   ...   ...
# 4966    152  Prey    0.490877   594   818
# 4967    152  Prey    0.487457   642   783
# 4968    152  Prey    0.451108  1003   985
# 4969    152  Prey    0.401255   981   767
# 4970    152  Prey    0.318015  1079   797
#
# [4971 rows x 5 columns]

# %%
'''def track_video(video):
    video_path = os.path.join(raw_video_folder, f"{video}.mp4")
    cap = cv2.VideoCapture(video_path)
    centroids_data = []
    frame_num = 0
    data=[]

    while True:
        success, frame = cap.read()
        if not success:
            break

        # statt model(frame) jetzt model.track(...)
        results = model.track(
            frame,
            conf=0.2,
            tracker="bytetrack.yaml",
            persist=True
        )

        # Ergebnisse durchgehen und Track-ID mit abspeichern
        for box in results[0].boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cx = (x1 + x2) // 2
            cy = (y1 + y2) // 2

            cls_id    = int(box.cls[0])
            label     = model.names[cls_id]
            conf      = float(box.conf[0])
            track_id  = int(box.id[0])  # <-- hier kommt die Track-ID

            data.append({
                "frame":      frame_num,
                "track_id":   track_id,
                "label":      label,
                "confidence": conf,
                "x":          cx,
                "y":          cy
            })

        frame_num += 1

    cap.release()

    # In DataFrame umwandeln und speichern
    tracking_data = pd.DataFrame(data)
    out_path = os.path.join(output_folder, f"tracked_movement_{video}.csv")
    tracking_data.to_csv(out_path, index=False)
    
    return tracking_data


tracking_data = track_video(video)
tracking_data'''

# %%
'''# {0: 'Predator', 1: 'Predator Head', 2: 'Prey', 3: 'Prey Head'}
predator = movement_data[movement_data['label'] == 'Predator Head']

if not os.path.exists("data/pred_movement.csv"):
    predator.to_csv("data/pred_movement.csv", index=False)

prey = movement_data[movement_data['label'] == 'Prey']

if not os.path.exists("data/prey_movement.csv"):
    prey.to_csv("data/prey_movement.csv", index=False)'''
# Out:
# '# {0: \'Predator\', 1: \'Predator Head\', 2: \'Prey\', 3: \'Prey Head\'}\npredator = movement_data[movement_data[\'label\'] == \'Predator Head\']\n\nif not os.path.exists("data/pred_movement.csv"):\n    predator.to_csv("data/pred_movement.csv", index=False)\n\nprey = movement_data[movement_data[\'label\'] == \'Prey\']\n\nif not os.path.exists("data/prey_movement.csv"):\n    prey.to_csv("data/prey_movement.csv", index=False)'

# %%
import os
import cv2
import numpy as np
import pandas as pd
from scipy.optimize import linear_sum_assignment

# Kalman Filter helper
def create_kalman_filter(dt=1.0, process_noise=1e-2, measurement_noise=1e-1):
    kf = cv2.KalmanFilter(4, 2)
    # State transition (constant velocity)
    kf.transitionMatrix = np.array([
        [1, 0, dt, 0],
        [0, 1, 0, dt],
        [0, 0, 1, 0],
        [0, 0, 0, 1]
    ], dtype=np.float32)
    # Measurement matrix
    kf.measurementMatrix = np.array([
        [1, 0, 0, 0],
        [0, 1, 0, 0]
    ], dtype=np.float32)
    # Noise covariances
    kf.processNoiseCov = np.eye(4, dtype=np.float32) * process_noise
    kf.measurementNoiseCov = np.eye(2, dtype=np.float32) * measurement_noise
    return kf


def process_video_with_kalman(video, raw_video_folder, output_folder,
                              num_fish=33, num_prey=32, num_pred=1, max_distance=50.0,
                              num_frames=100):
    video_path = os.path.join(raw_video_folder, f"{video}.mp4")
    cap = cv2.VideoCapture(video_path)
    centroids_data = []

    # --- First frame: detect and select exactly num_fish detections ---
    success, first_frame = cap.read()
    if not success:
        raise RuntimeError(f"Cannot read first frame of {video}")

    results = model(first_frame, conf=0.3)
    # Collect detections by label
    prey_dets, pred_dets = [], []  # each: (cx, cy, conf)
    for box in results[0].boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        cx, cy = (x1 + x2)//2, (y1 + y2)//2
        cls_id = int(box.cls[0])
        label = model.names[cls_id]
        conf = float(box.conf[0])
        if label.lower() == 'predator':
            pred_dets.append((cx, cy, conf))
        else:
            prey_dets.append((cx, cy, conf))
    # Handle counts
    if len(pred_dets) < num_pred or len(prey_dets) < num_prey:
        raise ValueError(f"Not enough detections: got {len(prey_dets)} prey, {len(pred_dets)} predator")
    # Select top confidences
    pred_dets = sorted(pred_dets, key=lambda x: x[2], reverse=True)[:num_pred]
    prey_dets = sorted(prey_dets, key=lambda x: x[2], reverse=True)[:num_prey]
    detections0 = prey_dets + pred_dets  # list of (cx, cy, conf)

    # Initialize trackers
    trackers = []  # [{'kf': kf, 'id': idx}]
    for idx, (cx, cy, _) in enumerate(detections0):
        kf = create_kalman_filter()
        init_state = np.array([[cx], [cy], [0], [0]], dtype=np.float32)
        kf.statePre = init_state.copy()
        kf.statePost = init_state.copy()
        kf.correct(np.array([[np.float32(cx)], [np.float32(cy)]]))
        trackers.append({'kf': kf, 'id': idx})
        centroids_data.append({
            'track_id': idx, 'frame': 0, 'x': cx, 'y': cy, 'imputed': False
        })

    # --- Subsequent frames ---
    frame_number = 1
    while frame_number < num_frames:
        success, frame = cap.read()
        if not success:
            break
        # Predict
        preds = [ (t['kf'].predict()[0,0], t['kf'].predict()[1,0]) for t in trackers ]
        # Detect
        results = model(frame, conf=0.3)
        dets = []  # (cx, cy)
        for box in results[0].boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            dets.append(((x1+x2)//2, (y1+y2)//2))
        # Associate
        matched, unmatched = [], []
        if dets:
            cost = np.zeros((len(trackers), len(dets)), dtype=np.float32)
            for i, (px, py) in enumerate(preds):
                for j, (dx, dy) in enumerate(dets): cost[i,j] = np.hypot(px-dx, py-dy)
            row, col = linear_sum_assignment(cost)
            for i in range(len(trackers)):
                if i not in row: unmatched.append(i)
            for ri, ci in zip(row, col):
                if cost[ri,ci] < max_distance:
                    matched.append((ri,ci))
                else:
                    unmatched.append(ri)
        else:
            unmatched = list(range(len(trackers)))
        # Update/Impute
        for ti, di in matched:
            cx, cy = dets[di]
            trackers[ti]['kf'].correct(np.array([[np.float32(cx)], [np.float32(cy)]]))
            centroids_data.append({'track_id': trackers[ti]['id'], 'frame': frame_number, 'x': cx, 'y': cy, 'imputed': False})
        for ti in unmatched:
            pred = trackers[ti]['kf'].statePost
            cx, cy = int(pred[0,0]), int(pred[1,0])
            centroids_data.append({'track_id': trackers[ti]['id'], 'frame': frame_number, 'x': cx, 'y': cy, 'imputed': True})
        frame_number += 1

    cap.release()
    # Export
    movement_data = pd.DataFrame(centroids_data)
    movement_data.to_csv(os.path.join(output_folder, f"movement_data_{video}.csv"), index=False)
    return movement_data

# %%
data1 = process_video_with_kalman(video, raw_video_folder, output_folder,
                              num_fish=33, max_distance=50.0)
# Out:
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 762.1ms
# Speed: 16.1ms preprocess, 762.1ms inference, 6.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 655.7ms
# Speed: 17.4ms preprocess, 655.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 644.4ms
# Speed: 22.2ms preprocess, 644.4ms inference, 3.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 664.0ms
# Speed: 15.8ms preprocess, 664.0ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 35 Preys, 914.4ms
# Speed: 18.0ms preprocess, 914.4ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 668.8ms
# Speed: 16.9ms preprocess, 668.8ms inference, 4.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 669.3ms
# Speed: 18.5ms preprocess, 669.3ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 654.4ms
# Speed: 18.0ms preprocess, 654.4ms inference, 3.4ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 647.6ms
# Speed: 18.6ms preprocess, 647.6ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 662.8ms
# Speed: 13.9ms preprocess, 662.8ms inference, 4.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 666.5ms
# Speed: 11.5ms preprocess, 666.5ms inference, 4.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 658.1ms
# Speed: 17.0ms preprocess, 658.1ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 651.8ms
# Speed: 18.3ms preprocess, 651.8ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 648.9ms
# Speed: 16.3ms preprocess, 648.9ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 664.0ms
# Speed: 13.7ms preprocess, 664.0ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 664.7ms
# Speed: 18.2ms preprocess, 664.7ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 660.1ms
# Speed: 10.5ms preprocess, 660.1ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 31 Preys, 819.7ms
# Speed: 14.7ms preprocess, 819.7ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 647.3ms
# Speed: 16.3ms preprocess, 647.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 648.7ms
# Speed: 16.9ms preprocess, 648.7ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 33 Preys, 665.9ms
# Speed: 17.0ms preprocess, 665.9ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 666.8ms
# Speed: 10.2ms preprocess, 666.8ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 33 Preys, 658.1ms
# Speed: 16.3ms preprocess, 658.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 660.3ms
# Speed: 16.3ms preprocess, 660.3ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 657.5ms
# Speed: 16.7ms preprocess, 657.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 28 Preys, 729.5ms
# Speed: 15.8ms preprocess, 729.5ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 667.2ms
# Speed: 17.9ms preprocess, 667.2ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 648.7ms
# Speed: 18.5ms preprocess, 648.7ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 819.9ms
# Speed: 17.3ms preprocess, 819.9ms inference, 2.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 682.6ms
# Speed: 16.1ms preprocess, 682.6ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 666.2ms
# Speed: 10.7ms preprocess, 666.2ms inference, 3.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 665.2ms
# Speed: 17.1ms preprocess, 665.2ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 662.9ms
# Speed: 10.9ms preprocess, 662.9ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 731.5ms
# Speed: 17.6ms preprocess, 731.5ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 656.5ms
# Speed: 17.6ms preprocess, 656.5ms inference, 1.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 657.1ms
# Speed: 14.9ms preprocess, 657.1ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 34 Preys, 653.4ms
# Speed: 15.4ms preprocess, 653.4ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 647.6ms
# Speed: 17.5ms preprocess, 647.6ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 754.4ms
# Speed: 73.0ms preprocess, 754.4ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 33 Preys, 649.0ms
# Speed: 11.5ms preprocess, 649.0ms inference, 3.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 33 Preys, 664.8ms
# Speed: 17.0ms preprocess, 664.8ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 30 Preys, 666.2ms
# Speed: 16.0ms preprocess, 666.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 29 Preys, 656.7ms
# Speed: 17.0ms preprocess, 656.7ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 32 Preys, 646.2ms
# Speed: 17.0ms preprocess, 646.2ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 31 Preys, 652.7ms
# Speed: 17.2ms preprocess, 652.7ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 30 Preys, 641.7ms
# Speed: 17.9ms preprocess, 641.7ms inference, 4.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 30 Preys, 656.9ms
# Speed: 18.3ms preprocess, 656.9ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 29 Preys, 685.7ms
# Speed: 16.7ms preprocess, 685.7ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 31 Preys, 652.8ms
# Speed: 16.3ms preprocess, 652.8ms inference, 4.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 29 Preys, 653.5ms
# Speed: 17.1ms preprocess, 653.5ms inference, 3.6ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 29 Preys, 649.2ms
# Speed: 16.8ms preprocess, 649.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 29 Preys, 646.7ms
# Speed: 16.3ms preprocess, 646.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 29 Preys, 669.0ms
# Speed: 16.1ms preprocess, 669.0ms inference, 2.5ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 31 Preys, 657.2ms
# Speed: 13.6ms preprocess, 657.2ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 657.8ms
# Speed: 12.3ms preprocess, 657.8ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 30 Preys, 651.2ms
# Speed: 18.1ms preprocess, 651.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 650.9ms
# Speed: 13.5ms preprocess, 650.9ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 653.1ms
# Speed: 17.0ms preprocess, 653.1ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 659.6ms
# Speed: 17.9ms preprocess, 659.6ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 29 Preys, 803.4ms
# Speed: 17.6ms preprocess, 803.4ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 30 Preys, 668.3ms
# Speed: 15.1ms preprocess, 668.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator Head, 29 Preys, 729.6ms
# Speed: 13.8ms preprocess, 729.6ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 2 Predator Heads, 31 Preys, 654.0ms
# Speed: 16.5ms preprocess, 654.0ms inference, 3.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 2 Predator Heads, 31 Preys, 685.4ms
# Speed: 19.9ms preprocess, 685.4ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 2 Predator Heads, 32 Preys, 675.4ms
# Speed: 13.4ms preprocess, 675.4ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 2 Predator Heads, 30 Preys, 679.7ms
# Speed: 16.3ms preprocess, 679.7ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 687.6ms
# Speed: 15.9ms preprocess, 687.6ms inference, 4.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 31 Preys, 666.7ms
# Speed: 17.2ms preprocess, 666.7ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 670.8ms
# Speed: 14.3ms preprocess, 670.8ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 667.2ms
# Speed: 16.4ms preprocess, 667.2ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 30 Preys, 652.1ms
# Speed: 15.5ms preprocess, 652.1ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 650.3ms
# Speed: 16.7ms preprocess, 650.3ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 28 Preys, 654.0ms
# Speed: 17.1ms preprocess, 654.0ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 28 Preys, 666.5ms
# Speed: 16.6ms preprocess, 666.5ms inference, 4.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 28 Preys, 668.9ms
# Speed: 15.4ms preprocess, 668.9ms inference, 4.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 28 Preys, 654.6ms
# Speed: 17.9ms preprocess, 654.6ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 28 Preys, 644.5ms
# Speed: 17.5ms preprocess, 644.5ms inference, 2.3ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 669.5ms
# Speed: 19.6ms preprocess, 669.5ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 643.6ms
# Speed: 17.7ms preprocess, 643.6ms inference, 2.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 660.9ms
# Speed: 21.7ms preprocess, 660.9ms inference, 2.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 818.5ms
# Speed: 17.7ms preprocess, 818.5ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 28 Preys, 658.8ms
# Speed: 18.6ms preprocess, 658.8ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 28 Preys, 641.6ms
# Speed: 18.4ms preprocess, 641.6ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 664.7ms
# Speed: 16.8ms preprocess, 664.7ms inference, 1.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 667.5ms
# Speed: 17.8ms preprocess, 667.5ms inference, 3.7ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 673.9ms
# Speed: 17.8ms preprocess, 673.9ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 647.0ms
# Speed: 10.9ms preprocess, 647.0ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 667.5ms
# Speed: 14.5ms preprocess, 667.5ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 648.9ms
# Speed: 16.8ms preprocess, 648.9ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 650.3ms
# Speed: 18.7ms preprocess, 650.3ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 743.8ms
# Speed: 18.1ms preprocess, 743.8ms inference, 1.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 32 Preys, 668.8ms
# Speed: 13.4ms preprocess, 668.8ms inference, 4.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 33 Preys, 663.2ms
# Speed: 16.7ms preprocess, 663.2ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 32 Preys, 650.2ms
# Speed: 16.6ms preprocess, 650.2ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 32 Preys, 658.1ms
# Speed: 10.1ms preprocess, 658.1ms inference, 1.9ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 1 Predator Head, 32 Preys, 667.2ms
# Speed: 17.4ms preprocess, 667.2ms inference, 3.8ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 32 Preys, 675.1ms
# Speed: 17.8ms preprocess, 675.1ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 29 Preys, 655.3ms
# Speed: 15.9ms preprocess, 655.3ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 30 Preys, 699.7ms
# Speed: 17.0ms preprocess, 699.7ms inference, 2.1ms postprocess per image at shape (1, 3, 736, 736)
#
# 0: 736x736 1 Predator, 2 Predator Heads, 31 Preys, 694.0ms
# Speed: 16.3ms preprocess, 694.0ms inference, 1.2ms postprocess per image at shape (1, 3, 736, 736)

# %%
test = data1[data1["track_id"] == 1]

# %%
test[:50]
# Out:
#       track_id  frame     x    y  imputed
# 1            1      0  1270  972    False
# 34           1      1  1270  971    False
# 67           1      2  1268  970    False
# 100          1      3  1266  970    False
# 133          1      4  1266  970    False
# 166          1      5  1265  969    False
# 199          1      6  1264  969    False
# 232          1      7  1262  966    False
# 265          1      8  1259  964    False
# 298          1      9  1258  963    False
# 331          1     10  1258  963    False
# 364          1     11  1256  962    False
# 397          1     12  1255  962    False
# 430          1     13  1252  962    False
# 463          1     14  1249  962    False
# 496          1     15  1248  959    False
# 529          1     16  1248  959    False
# 562          1     17  1246  957    False
# 595          1     18  1246  955    False
# 628          1     19  1245  953    False
# 661          1     20  1243  951    False
# 694          1     21  1239  949    False
# 727          1     22  1239  949    False
# 760          1     23  1236  949    False
# 793          1     24  1231  948    False
# 826          1     25  1228  947    False
# 859          1     26  1225  947    False
# 892          1     27  1222  946    False
# 925          1     28  1222  946    False
# 958          1     29  1215  946    False
# 991          1     30  1211  943    False
# 1053         1     31  1207  942     True
# 1086         1     32  1202  940     True
# 1120         1     33  1198  939     True
# 1153         1     34  1194  938     True
# 1156         1     35  1198  936    False
# 1189         1     36  1195  937    False
# 1222         1     37  1192  935    False
# 1255         1     38  1187  934    False
# 1288         1     39  1182  934    False
# 1321         1     40  1182  934    False
# 1354         1     41  1178  934    False
# 1387         1     42  1176  931    False
# 1420         1     43  1171  929    False
# 1453         1     44  1167  927    False
# 1486         1     45  1162  926    False
# 1519         1     46  1162  926    False
# 1552         1     47  1159  925    False
# 1585         1     48  1156  924    False
# 1618         1     49  1152  924    False
